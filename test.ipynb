# %%
import logging, sys, os
import json, requests
from dataclasses import dataclass
from datetime import datetime
import pandas as pd
from time import sleep
from typing import List
import hashlib
import inspect
from functools import lru_cache

## testing connection errors
class ConnectionErrorAdapter(requests.adapters.BaseAdapter):
    def send(self, request, stream=False, timeout=None, verify=True, cert=None, proxies=None):
        raise requests.exceptions.ConnectionError("Simulated Connection Error")
    
class RequestExceptionAdapter(requests.adapters.BaseAdapter):
    def send(self, request, stream=False, timeout=None, verify=True, cert=None, proxies=None):
        raise requests.exceptions.RequestException("Simulated Request Exception")

@dataclass
class dbtJob:
    """
    Parses a DBT job object from a dictionary.

    Args:
        obj: The dictionary representing the DBT job object.

    Returns:
        The corresponding `dbtJob` object.
    """
    job_id: str
    job_name: str
    job_description: str
    project_id: str
    environment_id: str
    created_at: datetime
    updated_at: datetime
    state: str
    deactivated: str
    schedule: str
    cron_humanized: str

    def __hash__(self):
        # Create a hashable representation of the object's data fields
        hashable_data = {
            "job_id": self.job_id,
            "state": self.state, 
            'created_at': self.created_at
        }

        # Generate a hash value using hashlib
        hash_object = hashlib.sha256()
        for key, value in hashable_data.items():
            hash_object.update(f"{key}:{value}".encode())

        return int(hash_object.hexdigest(), 16)

@dataclass
class dbtRun:
    """
    Parses a DBT run object from a dictionary.

    Args:
        obj: The dictionary representing the DBT run object.

    Returns:
        The corresponding `dbtRun` object.
    """
    run_id: int
    job_id: int
    environment_id: int
    project_id: int
    status: str
    created_at: datetime
    started_at: datetime
    finished_at: datetime
    in_progress: bool
    is_complete: bool
    is_success: bool
    is_error: bool
    is_cancelled: bool
    duration: str
    queued_duration: str
    run_duration: str
    can_retry: bool
    is_running: bool

    def __hash__(self):
        # Create a hashable representation of the object's data fields
        hashable_data = {
            "run_id": self.run_id,
            "created_at": self.created_at,
            "status": self.status
        }

        # Generate a hash value using hashlib
        hash_object = hashlib.sha256()
        for key, value in hashable_data.items():
            hash_object.update(f"{key}:{value}".encode())

        return int(hash_object.hexdigest(), 16)

@dataclass
class dbtEnvironment:
    """
    Parses a DBT environment object from a dictionary.

    Args:
        obj: The dictionary representing the DBT environment object.

    Returns:
        The corresponding `dbtEnvironment` object.
    """
    environment_id: int
    project_id: int
    connection_id: int
    repository_id: int
    name: str
    custom_branch: str
    updated_at: datetime
    state: int
 
    def __hash__(self):
        # Create a hashable representation of the object's data fields
        hashable_data = {
            "environment_id": self.environment_id,
            "state": self.state, 
            'updated_at': self.created_at
        }

        # Generate a hash value using hashlib
        hash_object = hashlib.sha256()
        for key, value in hashable_data.items():
            hash_object.update(f"{key}:{value}".encode())

        return int(hash_object.hexdigest(), 16)

@dataclass
class dbtRepository:
    """
    Parses a DBT repo object from a dictionary.

    Args:
        obj: The dictionary representing the DBT repo object.

    Returns:
        The corresponding `dbtRepository` object.
    """
    repository_id: int
    project_id: int
    project_name: str
    project_full_name: str
    remote_url: str
    state: int
    created_at: datetime
    updated_at: datetime

    def __hash__(self):
        # Create a hashable representation of the object's data fields
        hashable_data = {
            "repository_id": self.repository_id,
            "state": self.state, 
            'created_at': self.created_at
        }

        # Generate a hash value using hashlib
        hash_object = hashlib.sha256()
        for key, value in hashable_data.items():
            hash_object.update(f"{key}:{value}".encode())

        return int(hash_object.hexdigest(), 16)

@dataclass
class dbtConnection:
    """
    Parses a DBT connection object from a dictionary.

    Args:
        obj: The dictionary representing the DBT connection object.

    Returns:
        The corresponding `dbtConnection` object.
    """
    connection_id: int
    project_id: int
    conn_name: str
    conn_type: str
    conn_host: str
    conn_db: str
    conn_port: int
    state: int

    def __hash__(self):
        # Create a hashable representation of the object's data fields
        hashable_data = {
            "connection_id": self.connection_id,
            "state": self.state, 
        }

        # Generate a hash value using hashlib
        hash_object = hashlib.sha256()
        for key, value in hashable_data.items():
            hash_object.update(f"{key}:{value}".encode())

        return int(hash_object.hexdigest(), 16)

@dataclass
class dbtProject:
    """
    Parses a DBT project object from a dictionary.

    Args:
        obj: The dictionary representing the DBT project object.

    Returns:
        The corresponding `dbtProject` object.
    """
    project_id: int
    project_name: str
    connection_id: int
    repository_id:int
    created_at: datetime
    updated_at:datetime
    state: int
   
    def __hash__(self):
        # Create a hashable representation of the object's data fields
        hashable_data = {
            "project_id": self.project_id,
            "state": self.state, 
            'created_at': self.created_at
        }

        # Generate a hash value using hashlib
        hash_object = hashlib.sha256()
        for key, value in hashable_data.items():
            hash_object.update(f"{key}:{value}".encode())

        return int(hash_object.hexdigest(), 16)

@dataclass
class dbtModel:
    database: str
    schema: str
    model_name: str

    def __hash__(self):
        # Create a hashable representation of the object's data fields
        hashable_data = {
            "database": self.run_id,
            "schema": self.created_at,
            "model_name": self.status
        }

        # Generate a hash value using hashlib
        hash_object = hashlib.sha256()
        for key, value in hashable_data.items():
            hash_object.update(f"{key}:{value}".encode())

        return int(hash_object.hexdigest(), 16)





class AuthType:
    def __init__(self):
        None

    def auth_header(self):
        raise NotImplementedError("Abstract Method")
    
class AuthApiKey(AuthType):
    def __init__(self, **kwargs):
        super().__init__()
        try:  
            self.api_key = os.environ['DBT_API_KEY']
        except KeyError:
            try: 
                self.api_key = kwargs['dbt_api_key']
            except KeyError:
                logging.error('No API key found. Either set up DBT_API_KEY in your environment or pass dbt_api_key = "abc123" when initiating a dbtClient object. Exiting... ')
                sys.exit(1)

    def auth_header(self):
        return {
                'Accept': 'application/json',
                'Authorization': f'Bearer {self.api_key}'
            }
    
class dbtClient():

    DBT_ENDPOINTS = {
        'jobs': 'jobs',
        'runs': 'runs', 
        'projects': 'projects', 
        'environments': 'environments', 
        'connections': 'connections', 
        'repositories': 'repositories'
    }
 
    def __init__(self, base_url:str, api_version:str, account_id:str, env:str='local', auth_type:str = 'api_key', **kwargs):
        """
            Initializes the DBT API client with the specified URL, API version, account ID, and authentication type.

            Args:
                url (str): The base URL of the DBT API.
                api_version (str): The API version to use.
                account_id (str): The ID of the DBT account.
                auth_type (str, optional): The authentication type to use. Defaults to `api_key`.
                **kwargs: Additional keyword arguments.
        """
        if base_url.endswith("/"):
            url = f'{base_url}{api_version}/accounts/{account_id}'
        else:
            url = f'{base_url}/{api_version}/accounts/{account_id}'
        self.url = url
        self.session = requests.Session()
        AUTH_MAPPING = {
            'api_key': AuthApiKey(**kwargs)
        }
        auth = AUTH_MAPPING[auth_type]
        self.headers = auth.auth_header()
        self.session.headers.update(self.headers)
        self.env = env
        # test connection errors
        # self.session.mount("http://", ConnectionErrorAdapter())
        # self.session.mount("https://", ConnectionErrorAdapter())
        ## test request errors
        # self.session.mount("http://", RequestExceptionAdapter())
        # self.session.mount("https://", RequestExceptionAdapter())
        return
    
    @staticmethod
    def parse_dbt_job(obj) -> dbtJob : 
        job_id = obj['id']
        job_name = obj['name']
        job_description = obj['description']
        # job_description = 'testing'
        project_id = obj['project_id']
        environment_id = obj['environment_id']
        created_at = obj['created_at']
        updated_at = obj['updated_at']
        state = obj['state']
        deactivated = obj['deactivated']
        cron_schedule = obj['schedule']['cron']
        cron_humanized = obj['cron_humanized']
        parsed_object = dbtJob(job_id, job_name, job_description, project_id, environment_id, created_at, updated_at, state, deactivated, cron_schedule, cron_humanized)
        return parsed_object
    
    @staticmethod
    def parse_dbt_run(obj) -> dbtRun : 
        run_id = obj['id']
        job_id = obj['job_id']
        environment_id = obj['environment_id']
        project_id = obj['project_id']
        status = obj['status']
        created_at = obj['created_at']
        started_at = obj['started_at']
        finished_at = obj['finished_at']
        in_progress = obj['in_progress']
        is_complete = obj['is_complete']
        is_success = obj['is_success']
        is_error = obj['is_error']
        is_cancelled = obj['is_cancelled']
        duration = obj['duration']
        queued_duration = obj['queued_duration']
        run_duration = obj['run_duration']
        can_retry = obj['can_retry']
        is_running = obj['is_running']

        parsed_object = dbtRun(
            run_id, job_id, environment_id, project_id,
            status, 
            created_at, started_at, finished_at, 
            in_progress, is_complete, is_success, is_error, is_cancelled, 
            duration, queued_duration, run_duration, 
            can_retry, is_running
        )
        return parsed_object
    
    @staticmethod
    def parse_dbt_environment(obj) -> dbtEnvironment:
        environment_id = obj['id']
        project_id = obj['project_id']
        connection_id = obj['connection_id']
        repository_id = obj['repository_id']
        name = obj['name']
        custom_branch = obj['custom_branch']
        updated_at = obj['updated_at']
        state = obj['state']
        parsed_obj = dbtEnvironment(environment_id,project_id, connection_id, repository_id, name, custom_branch, updated_at, state )
        return parsed_obj

    @staticmethod
    def parse_dbt_repository(obj) -> dbtRepository:
        repository_id = obj['id']
        project_id = obj['project_id']
        project_name= obj['name']
        project_full_name = obj['full_name']
        remote_url = obj['remote_url']
        state = obj['state']
        created_at = obj['created_at']
        updated_at = obj['updated_at']

        parsed_obj = dbtRepository(repository_id, project_id, project_name, project_full_name, remote_url, state, created_at, updated_at)
        return parsed_obj

    @staticmethod
    def parse_dbt_connection(obj) -> dbtConnection:
        connection_id = obj['id']
        project_id = obj['dbt_project_id']
        conn_name = obj['name']
        conn_type = obj['type']
        conn_host = obj['hostname']
        conn_db = obj['dbname']
        conn_port = obj['port']
        state = obj['state']

        parsed_obj = dbtConnection(connection_id, project_id, conn_name, conn_type, conn_host, conn_db, conn_port, state)
        return parsed_obj

    @staticmethod
    def parse_dbt_project(obj) -> dbtProject:
        project_id = obj['id']
        project_name = obj['name']
        connection_id = obj['connection_id']
        repository_id = obj['repository_id']
        created_at = obj['created_at']
        updated_at = obj['updated_at']
        state = obj['state']

        parsed_obj = dbtProject(project_id, project_name, connection_id, repository_id, created_at, updated_at, state)
        return parsed_obj

    @staticmethod
    def parse_dbt_model(obj) -> dbtModel : 
        database = obj['database']
        schema = obj['schema']
        model_name = obj['name']
        parsed_object = dbtModel(database, schema, model_name)
        return parsed_object

    def _make_request(self, endpoint, data=None, pagination_params = {}, filter_params = {}):
        """
        Makes a request to the DBT API and handles the response.

        Args:
            endpoint: The endpoint to make the request to.
            data: The data to send in the request body.

        Returns:
            The response data from the API and pagination info
        """
        retries = 3
        retry_delay = 1
        url = f"{self.url}/{endpoint}"

        for retry in range(retries + 1):
            try:
                params_merged = {**pagination_params, **filter_params}
                if data:
                    res = self.session.get(url, json=data, params=json.loads(json.dumps(params_merged)))
                else:
                    res = self.session.get(url, params=json.loads(json.dumps(params_merged)))

                if res.status_code == 200:
                    if inspect.stack()[1].function == 'get_manifest':
                        return res.text
                    res_dict = json.loads(res.text)
                    res_data = res_dict.get('data', None)
                    res.close()
                    if res_data:
                        res_pagination = res_dict.get('extra', None)
                        logging.critical(res_pagination)
                        return res_data, res_pagination
                    else:
                        raise Exception("No valid data found in the response")
                else:
                    raise Exception(f"Request returned the following non-200 response code {res.status_code}")

            ## try again in case of connection networking issues
            except requests.exceptions.ConnectionError as e:
                logging.error(f"Error: Unable to connect to DBT API server: {e}")
                logging.warning(f"Trying again...")
                if retry < retries:
                    sleep(retry_delay * (2 ** retry))
                else:
                    logging.error(f'Max retries reached. Exiting with exit code 1')
                    sys.exit(1)
            ## try again in case of request issues
            except requests.exceptions.RequestException as e:
                logging.error(f"Error: Unable to make request to DBT API: {e}")
                logging.warning(f"Trying again...")
                if retry < retries:
                    sleep(retry_delay * (2 ** retry))
                else:
                    logging.error(f'Max retries reached. Exiting with exit code 1')
                    sys.exit(1)
            ## exit in case of non-200 status or invalid data
            except Exception as e:
                logging.error(f'Failed to fetch valid data, exiting with error code 1: {e}')
                sys.exit(1)

    def _make_paginated_request(self, endpoint: str, limit=100, **kwargs):
        all_records = []
        first_data_batch, pagination_data = self._make_request(endpoint, pagination_params={"limit": limit, "offset": 0}, **kwargs)
        
        for record in  first_data_batch:
            all_records.append(record)

        if self.env == 'local':
            total_records_to_fetch = min(limit*3+1, pagination_data["pagination"]["total_count"])
            logging.warning(f'Limiting records to fetch to: {total_records_to_fetch}')
        else:
            total_records_to_fetch = pagination_data["pagination"]["total_count"]
            logging.warning(f'Total records to fetch: {total_records_to_fetch}')
        
        ## no pagination required
        if total_records_to_fetch <= limit: 
            return all_records
        
        total_fetched_records = limit
        offset = limit

        while True :
            data, _ = self._make_request(endpoint, pagination_params={"limit": limit, "offset": offset}, **kwargs)
            for record in data:
                all_records.append(record)
                total_fetched_records += 1
                if total_fetched_records == total_records_to_fetch:
                    return all_records
            offset += limit

    def get_jobs(self):
        """
            Returns a list of all DBT jobs as dbtJob objects
        """
        jobs_data = self._make_paginated_request(self.DBT_ENDPOINTS['jobs'])
        return [self.parse_dbt_job(job) for job in jobs_data]

    def get_job_by_id(self, job_id):
        jobs_data = self._make_request(f"{self.DBT_ENDPOINTS['jobs']}/{job_id}")
        return self.parse_dbt_job(jobs_data)

    def get_runs(self, created_from = datetime(2020,1,1), created_to = datetime.now()):
        """
            Returns a list of all DBT runs as dbtRun objects
        """
        created_from_formatted = created_from.strftime("%Y-%m-%d %H:%M:%S")
        created_to_formatted = created_to.strftime("%Y-%m-%d %H:%M:%S")
        filter_params = {
            'created_at__range': f'["{created_from_formatted}", "{created_to_formatted}"]'
        }
        logging.critical(f'Using the following filter params {filter_params}')
        runs_data = self._make_paginated_request(self.DBT_ENDPOINTS['runs'], filter_params = filter_params)
        return [self.parse_dbt_run(run) for run in runs_data]

    def get_runs_gt_id(self, id__gt=0):
        """
            Returns a list of all DBT runs as dbtRun objects
        """
        filter_params = {
            'id__gt': id__gt
        }
        logging.critical(f'Using the following filter params {filter_params}')
        runs_data = self._make_paginated_request(self.DBT_ENDPOINTS['runs'], filter_params = filter_params)
        return [self.parse_dbt_run(run) for run in runs_data]
    
    def get_run_by_id(self, run_id):
        """
            Returns a list of all DBT runs as dbtRun objects
        """
        runs_data = self._make_request(f"{self.DBT_ENDPOINTS['runs']}/{run_id}")
        return self.parse_dbt_run(runs_data) 

    def get_environments(self):
        """
            Returns a list of all DBT environments as dbtEnv objects
        """
        envs_data = self._make_paginated_request(self.DBT_ENDPOINTS['environments'])
        return [self.parse_dbt_environment(env) for env in envs_data]
    
    def get_environment_by_id(self, env_id):
        envs_data = self._make_request(f"{self.DBT_ENDPOINTS['environments']}/{env_id}")
        return self.parse_dbt_environment(envs_data)
    
    def get_projects(self):
        """
            Returns a list of all DBT projects as dbtProject objects
        """
        projects_data = self._make_paginated_request(self.DBT_ENDPOINTS['projects'])
        return [self.parse_dbt_project(project) for project in projects_data]
    
    def get_project_by_id(self, project_id):
        projects_data = self._make_request(f"{self.DBT_ENDPOINTS['projects']}/{project_id}")
        return self.parse_dbt_project(projects_data)
    
    def get_connections(self):
        """
            Returns a list of all DBT connections as dbtConnection objects
        """
        connections_data = self._make_paginated_request(self.DBT_ENDPOINTS['connections'])
        return [self.parse_dbt_connection(conn) for conn in connections_data]
    
    def get_connection_by_id(self, connection_id):
        connections_data = self._make_request(f"{self.DBT_ENDPOINTS['connections']}/{connection_id}")
        return self.parse_dbt_connection(connections_data)
    
    def get_repositories(self):
        """
            Returns a list of all DBT repositories as dbtRepository objects
        """
        repositories_data = self._make_paginated_request(self.DBT_ENDPOINTS['repositories'])
        return [self.parse_dbt_repository(repo) for repo in repositories_data]
    
    def get_repository_by_id(self, repository_id):
        repositories_data = self._make_request(f"{self.DBT_ENDPOINTS['repositories']}/{repository_id}")
        return self.parse_dbt_repository(repositories_data)

    @lru_cache(maxsize = None)
    def get_manifest(self, job_id):
        current_accept = self.headers["Accept"]
        self.headers["Accept"] = 'text/html'
        self.session.headers.update(self.headers)
        manifest = self._make_request(f"jobs/{job_id}/artifacts/manifest.json")
        self.headers["Accept"] = current_accept
        self.session.headers.update(self.headers)
        return manifest
    
    @staticmethod 
    def check_duplicates(dataclass_list):
        seen = set()
        for o in dataclass_list:
            if o in seen:
                logging.error(f'found at least one duplicate object: {o}')
                return True
            else:
                seen.add(o)
        return False

    @staticmethod
    def dataclass_list_to_df(dataclass_objects_list):
        serialized_data = []

        for dataclass_object in dataclass_objects_list:
            serialized_data_item = {}

            for field_name, field_value in dataclass_object.__dict__.items():
                serialized_data_item[field_name] = field_value

            serialized_data.append(serialized_data_item)

        return pd.DataFrame(serialized_data)

    def close_session(self):
        try:
            self.session.close()
            logging.info("Closed API session")
        except Exception as e:
            logging.error("Error closing API session")
            raise e

# %%
base_url = 'https://cloud.getdbt.com/api/'
version = 'v2'
account_id = 38487

dbt = dbtClient(base_url, version, account_id)

# %%
mani = dbt.get_manifest(185935)
mani
# Out:
# '{"metadata": {"dbt_schema_version": "https://schemas.getdbt.com/dbt/manifest/v8.json", "dbt_version": "1.4.9", "generated_at": "2024-02-23T05:00:30.694499Z", "invocation_id": "a9169a09-29ab-498a-b0c8-30d2129b17f2", "env": {"DBT_CLOUD_PROJECT_ID": "165090", "DBT_CLOUD_RUN_ID": "255080100", "DBT_CLOUD_JOB_ID": "185935", "DBT_CLOUD_RUN_REASON": "scheduled", "DBT_CLOUD_RUN_REASON_CATEGORY": "scheduled", "DBT_CLOUD_RUN_TRIGGER_CATEGORY": "RUN_REASON_CATEGORY_SCHEDULED", "DBT_CLOUD_ENVIRONMENT_ID": "124802", "DBT_CLOUD_ACCOUNT_ID": "38487"}, "project_id": "4ca86205973bc9bc3c8afc23d03332cb", "user_id": "8e18a6db-4268-43d5-ad97-42eacffec699", "send_anonymous_usage_stats": true, "adapter_type": "redshift"}, "nodes": {"model.VEB_trans_veb.020_bc_customers": {"database": "terdwh", "schema": "horsum", "name": "020_bc_customers", "resource_type": "model", "package_name": "VEB_trans_veb", "path": "archive/020_bc_customers.sql", "original_file_path": "models/archive/020_bc_customers.sql", "unique_id": "model.VEB_trans_veb.020_bc_customers", "fqn": ["VEB_trans_veb", "archive", "020_bc_customers"], "alias": "020_bc_customers", "checksum": {"name": "sha256", "checksum": "ef8c2f9ae0ab5b3db3a11ee1de3abd5ee761505b1ce1bbb35886b9096863fd54"}, "config": {"enabled": true, "alias": null, "schema": null, "database": null, "tags": [], "meta": {}, "materialized": "table", "incremental_strategy": null, "persist_docs": {}, "quoting": {}, "column_types": {}, "full_refresh": null, "unique_key": null, "on_schema_change": "ignore", "grants": {}, "packages": [], "docs": {"show": true, "node_color": null}, "dist": "bc_klantnummer", "post-hook": [], "pre-hook": []}, "tags": [], "description": "", "columns": {}, "meta": {}, "docs": {"show": true, "node_color": null}, "patch_path": null, "build_path": null, "deferred": false, "unrendered_config": {"materialized": "table", "dist": "bc_klantnummer"}, "created_at": 1708664431.489237, "relation_name": "\\"terdwh\\".\\"horsum\\".\\"020_bc_customers\\"", "raw_code": "{{ config(materialized=\'table\', dist=\'bc_klantnummer\') }}\\r\\nSELECT \\r\\n    c.number AS bc_klantnummer, \\r\\n    c.displayname AS bc_klantnaam, \\r\\n    \\"replace\\"(upper(regexp_replace(COALESCE(c.taxregistrationnumber, \'\'::character varying)::text, \'[^a-z,0-9]*\'::text, \'\'::text, 1, \'i\'::text)), \'BTW\'::text, \'\'::text) AS bc_btwnr, \\r\\n    c.taxliable AS bc_btwplichtig, \\r\\n    btrim((c.addressline1::text || \' \'::text) || c.addressline2::text) AS bc_adres, \\r\\n    COALESCE(c.postalcode::character varying, \'\'::character varying) AS bc_postcode, \\r\\n    COALESCE(c.city, \'\'::character varying) AS bc_stad, \\r\\n    COALESCE(c.state, \'\'::character varying) AS bc_provincie, \\r\\n    CASE\\r\\n        WHEN COALESCE(c.country, \'\'::character varying)::text = \'BE\'::text THEN \'Belgi\\u00eb\'::character varying\\r\\n        ELSE COALESCE(c.country, \'\'::character varying)\\r\\n    END AS bc_land\\r\\nFROM {{ ref(\'010_bc_customers\') }} c", "language": "sql", "refs": [["010_bc_customers"]], "sources": [], "metrics": [], "depends_on": {"macros": [], "nodes": ["model.VEB_trans_veb.010_bc_customers"]}, "compiled_path": null}, "model.VEB_trans_veb.010_dyn_veb_city": {"database": "terdwh", "schema": "horsum", "name": "010_dyn_veb_city", "resource_type": "model", "package_name": "VEB_trans_veb", "path": "archive/010_dyn_veb_city.sql", "original_file_path": "models/archive/010_dyn_veb_city.sql", "unique_id": "model.VEB_trans_veb.010_dyn_veb_city", "fqn": ["VEB_trans_veb", "archive", "010_dyn_veb_city"], "alias": "010_dyn_veb_city", "checksum": {"name": "sha256", "checksum": "3f69ebec3e6ad0552b59db1efcd3cdfcfbd554e8a699c6b34c08444ef0233469"}, "config": {"enabled": true, "alias": null, "schema": null, "database": null, "tags": [], "meta": {}, "materialized": "table", "incremental_strategy": null, "persist_docs": {}, "quoting": {}, "column_types": {}, "full_refresh": null, "unique_key": null, "on_schema_change": "ignore", "grants": { ...

# %%
a = json.loads(mani)
a
# Out:
# {'metadata': {'dbt_schema_version': 'https://schemas.getdbt.com/dbt/manifest/v8.json',
#   'dbt_version': '1.4.9',
#   'generated_at': '2024-02-23T05:00:30.694499Z',
#   'invocation_id': 'a9169a09-29ab-498a-b0c8-30d2129b17f2',
#   'env': {'DBT_CLOUD_PROJECT_ID': '165090',
#    'DBT_CLOUD_RUN_ID': '255080100',
#    'DBT_CLOUD_JOB_ID': '185935',
#    'DBT_CLOUD_RUN_REASON': 'scheduled',
#    'DBT_CLOUD_RUN_REASON_CATEGORY': 'scheduled',
#    'DBT_CLOUD_RUN_TRIGGER_CATEGORY': 'RUN_REASON_CATEGORY_SCHEDULED',
#    'DBT_CLOUD_ENVIRONMENT_ID': '124802',
#    'DBT_CLOUD_ACCOUNT_ID': '38487'},
#   'project_id': '4ca86205973bc9bc3c8afc23d03332cb',
#   'user_id': '8e18a6db-4268-43d5-ad97-42eacffec699',
#   'send_anonymous_usage_stats': True,
#   'adapter_type': 'redshift'},
#  'nodes': {'model.VEB_trans_veb.020_bc_customers': {'database': 'terdwh',
#    'schema': 'horsum',
#    'name': '020_bc_customers',
#    'resource_type': 'model',
#    'package_name': 'VEB_trans_veb',
#    'path': 'archive/020_bc_customers.sql',
#    'original_file_path': 'models/archive/020_bc_customers.sql',
#    'unique_id': 'model.VEB_trans_veb.020_bc_customers',
#    'fqn': ['VEB_trans_veb', 'archive', '020_bc_customers'],
#    'alias': '020_bc_customers',
#    'checksum': {'name': 'sha256',
#     'checksum': 'ef8c2f9ae0ab5b3db3a11ee1de3abd5ee761505b1ce1bbb35886b9096863fd54'},
#    'config': {'enabled': True,
#     'alias': None,
#     'schema': None,
#     'database': None,
#     'tags': [],
#     'meta': {},
#     'materialized': 'table',
#     'incremental_strategy': None,
#     'persist_docs': {},
#     'quoting': {},
#     'column_types': {},
#     'full_refresh': None,
#     'unique_key': None,
#     'on_schema_change': 'ignore',
#     'grants': {},
#     'packages': [],
#     'docs': {'show': True, 'node_color': None},
#     'dist': 'bc_klantnummer',
#     'post-hook': [],
#     'pre-hook': []},
#    'tags': [],
#    'description': '',
#    'columns': {},
#    'meta': {},
#    'docs': {'show': True, 'node_color': None},
#    'patch_path': None,
#    'build_path': None,
#    'deferred': False,
#    'unrendered_config': {'materialized': 'table', 'dist': 'bc_klantnummer'},
#    'created_at': 1708664431.489237,
#    'relation_name': '"terdwh"."horsum"."020_bc_customers"',
#    'raw_code': '{{ config(materialized=\'table\', dist=\'bc_klantnummer\') }}\r\nSELECT \r\n    c.number AS bc_klantnummer, \r\n    c.displayname AS bc_klantnaam, \r\n    "replace"(upper(regexp_replace(COALESCE(c.taxregistrationnumber, \'\'::character varying)::text, \'[^a-z,0-9]*\'::text, \'\'::text, 1, \'i\'::text)), \'BTW\'::text, \'\'::text) AS bc_btwnr, \r\n    c.taxliable AS bc_btwplichtig, \r\n    btrim((c.addressline1::text || \' \'::text) || c.addressline2::text) AS bc_adres, \r\n    COALESCE(c.postalcode::character varying, \'\'::character varying) AS bc_postcode, \r\n    COALESCE(c.city, \'\'::character varying) AS bc_stad, \r\n    COALESCE(c.state, \'\'::character varying) AS bc_provincie, \r\n    CASE\r\n        WHEN COALESCE(c.country, \'\'::character varying)::text = \'BE\'::text THEN \'België\'::character varying\r\n        ELSE COALESCE(c.country, \'\'::character varying)\r\n    END AS bc_land\r\nFROM {{ ref(\'010_bc_customers\') }} c',
#    'language': 'sql',
#    'refs': [['010_bc_customers']],
#    'sources': [],
#    'metrics': [],
#    'depends_on': {'macros': [],
#     'nodes': ['model.VEB_trans_veb.010_bc_customers']},
#    'compiled_path': None},
#   'model.VEB_trans_veb.010_dyn_veb_city': {'database': 'terdwh',
#    'schema': 'horsum',
#    'name': '010_dyn_veb_city',
#    'resource_type': 'model',
#    'package_name': 'VEB_trans_veb',
#    'path': 'archive/010_dyn_veb_city.sql',
#    'original_file_path': 'models/archive/010_dyn_veb_city.sql',
#    'unique_id': 'model.VEB_trans_veb.010_dyn_veb_city',
#    'fqn': ['VEB_trans_veb', 'archive', '010_dyn_veb_city'],
#    'alias': '010_dyn_veb_city',
#    'checksum': {'name': 'sha256',
#     'checksum': '3f69ebec3e6ad0552b59db1efcd3cdfcfbd554e8a699c6b34c08444ef0233469'},
#    'config': {'enabled': True,
#     'alias': None,
#     'schema': None,
#     'database': None,
#     'tags': [],
#     'meta': {},
#     'materialized': 'table',
#     'incremental_strategy': None,
#     'persist_docs': {},
#     'quoting': {},
#     'column_types': {},
#     'full_refresh': None,
#     'unique_key': None,
#     'on_schema_change': 'ignore',
#     'grants': {},
#     'packages': [],
#     'docs': {'show': True, 'node_color': None},
#     'post-hook': [],
#     'pre-hook': []},
#    'tags': [],
#    'description': '',
#    'columns': {},
#    'meta': {},
#    'docs': {'show': True, 'node_color': None},
#    'patch_path': None,
#    'build_path': None,
#    'deferred': False,
#    'unrendered_config': {'materialized': 'table'},
#    'created_at': 1708664431.50066,
#    'relation_name': '"terdwh"."horsum"."010_dyn_veb_city"',
#    'raw_code': '{{ config(materialized=\'table\') }}\r\nselect *, \r\n"$path" source_file ,\r\nto_timestamp(substring("$path",43,14),\'YYYYMMDDHH24MISS\') utc_processing_date \r\nfrom {{source(\'ingest_dynamics\', \'veb_city\') }}\r\nwhere utc_processing_date in\r\n\t(\r\n\tselect max(to_timestamp(substring("$path",43,14),\'YYYYMMDDHH24MISS\')) last_processing_date\r\n\tfrom {{ source(\'ingest_dynamics\', \'veb_city\') }}\r\n\t)',
#    'language': 'sql',
#    'refs': [],
#    'sources': [['ingest_dynamics', 'veb_city']],
#    'metrics': [],
#    'depends_on': {'macros': [],
#     'nodes': ['source.VEB_trans_veb.ingest_dynamics.veb_city']},
#    'compiled_path': None},
#   'model.VEB_trans_veb.010_dyn_veb_province': {'database': 'terdwh',
#    'schema': 'horsum',
#    'name': '010_dyn_veb_province',
#    'resource_type': 'model',
#    'package_name': 'VEB_trans_veb',
#    'path': 'archive/010_dyn_veb_province.sql',
#    'original_file_path': 'models/archive/010_dyn_veb_province.sql',
#    'unique_id': 'model.VEB_trans_veb.010_dyn_veb_province',
#    'fqn': ['VEB_trans_veb', 'archive', '010_dyn_veb_province'],
#    'alias': '010_dyn_veb_province',
#    'checksum': {'name': 'sha256',
#     'checksum': '928bb43a2d2a8c7844b5179a2b6fb80e70f260ebfa250bed7c323ef16d306d21'},
#    'config': {'enabled': True,
#     'alias': None,
#     'schema': None,
#     'database': None,
#     'tags': [],
#     'meta': {},
#     'materialized': 'table',
#     'incremental_strategy': None,
#     'persist_docs': {},
#     'quoting': {},
#     'column_types': {},
#     'full_refresh': None,
#     'unique_key': None,
#     'on_schema_change': 'ignore',
#     'grants': {},
#     'packages': [],
#     'docs': {'show': True, 'node_color': None},
#     'post-hook': [],
#     'pre-hook': []},
#    'tags': [],
#    'description': '',
#    'columns': {},
#    'meta': {},
#    'docs': {'show': True, 'node_color': None},
#    'patch_path': None,
#    'build_path': None,
#    'deferred': False,
#    'unrendered_config': {'materialized': 'table'},
#    'created_at': 1708664431.5033574,
#    'relation_name': '"terdwh"."horsum"."010_dyn_veb_province"',
#    'raw_code': '{{ config(materialized=\'table\') }}\r\nselect *, \r\n"$path" source_file ,\r\nto_timestamp(substring("$path",46,14),\'YYYYMMDDHH24MISS\') utc_processing_date \r\nfrom {{source(\'ingest_dynamics\', \'veb_province\') }}\r\nwhere utc_processing_date in\r\n\t(\r\n\tselect max(to_timestamp(substring("$path",46,14),\'YYYYMMDDHH24MISS\')) last_processing_date\r\n\tfrom {{ source(\'ingest_dynamics\', \'veb_province\') }}\r\n\t)',
#    'language': 'sql',
#    'refs': [],
#    'sources': [['ingest_dynamics', 'veb_province']],
#    'metrics': [],
#    'depends_on': {'macros': [],
#     'nodes': ['source.VEB_trans_veb.ingest_dynamics.veb_province']},
#    'compiled_path': None},
#   'model.VEB_trans_veb.010_bc_customers': {'database': 'terdwh',
#    'schema': 'horsum',
#    'name': '010_bc_customers',
#    'resource_type': 'model',
#    'package_name': 'VEB_trans_veb',
#    'path': 'archive/010_bc_customers.sql',
#    'original_file_path': 'models/archive/010_bc_customers.sql',
#    'unique_id': 'model.VEB_trans_veb.010_bc_customers',
#    'fqn': ['VEB_trans_veb', 'archive', '010_bc_customers'],
#    'alias': '010_bc_customers',
#    'checksum': {'name': 'sha256',
#     'checksum': 'ed4b3c53413d215fe2003091011de01219434b3ef7cb87f743da9ae103cf5e44'},
#    'config': {'enabled': True,
#     'alias': None,
#     'schema': None,
#     'database': None,
#     'tags': [],
#     'meta': {},
#     'materialized': 'table',
#     'incremental_strategy': None,
#     'persist_docs': {},
#     'quoting': {},
#     'column_types': {},
#     'full_refresh': None,
#     'unique_key': None,
#     'on_schema_change': 'ignore',
#     'grants': {},
#     'packages': [],
#     'docs': {'show': True, 'node_color': None},
#     'dist': 'id',
#     'post-hook': [],
#     'pre-hook': []},
#    'tags': [],
#    'description': '',
#    'columns': {},
#    'meta': {},
#    'docs': {'show': True, 'node_color': None},
#    'patch_path': None,
#    'build_path': None,
#    'deferred': False,
#    'unrendered_config': {'materialized': 'table', 'dist': 'id'},
#    'created_at': 1708664431.5058694,
#    'relation_name': '"terdwh"."horsum"."010_bc_customers"',
#    'raw_code': "{{ config(materialized='table', dist='id') }}\r\nselect *\r\nfrom ingest.bc_customers",
#    'language': 'sql',
#    'refs': [],
#    'sources': [],
#    'metrics': [],
#    'depends_on': {'macros': [], 'nodes': []},
#    'compiled_path': None},
#   'model.VEB_trans_veb.020_dyn_accounts': {'database': 'terdwh',
#    'schema': 'horsum',
#    'name': '020_dyn_accounts',
#    'resource_type': 'model',
#    'package_name': 'VEB_trans_veb',
#    'path': 'archive/020_dyn_accounts.sql',
#    'original_file_path': 'models/archive/020_dyn_accounts.sql',
#    'unique_id': 'model.VEB_trans_veb.020_dyn_accounts',
#    'fqn': ['VEB_trans_veb', 'archive', '020_dyn_accounts'],
#    'alias': '020_dyn_accounts',
#    'checksum': {'name': 'sha256',
#     'checksum': 'a3bb4b080c7e5d5d8f08a7322f0cd3910f9cea406044deb502b7afefcb5aea57'},
#    'config': {'enabled': True,
#     'alias': None,
#     'schema': None,
#     'database': None,
#     'tags': [],
#     'meta': {},
#     'materialized': 'table',
#     'incremental_strategy': None,
#     'persist_docs': {},
#     'quoting': {},
#     'column_types': {},
#     'full_refresh': None,
#     'unique_key': None,
#     'on_schema_change': 'ignore',
#     'grants': {},
#     'packages': [],
#     'docs': {'show': True, 'node_color': None},
#     'dist': 'crm_klantnummer',
#     'post-hook': [],
#     'pre-hook': []},
#    'tags': [],
#    'description': '',
#    'columns': {},
#    'meta': {},
#    'docs': {'show': True, 'node_color': None},
#    'patch_path': None,
#    'build_path': None,
#    'deferred': False,
#    'unrendered_config': {'materialized': 'table', 'dist': 'crm_klantnummer'},
#    'created_at': 1708664431.5083435,
#    'relation_name': '"terdwh"."horsum"."020_dyn_accounts"',
#    'raw_code': "{{ config(materialized='table', dist='crm_klantnummer') }}\r\nSELECT \r\ncrm.accountnumber AS crm_klantnummer, \r\ncrm.name AS crm_klantnaam, \r\n        CASE\r\n            WHEN lower(crm.veb_sync_el::text) = 'true'::text THEN true\r\n            ELSE false\r\n        END AS crm_synclynx, \r\n        CASE\r\n            WHEN lower(crm.veb_sync_bc::text) = 'true'::text THEN true\r\n            ELSE false\r\n        END AS crm_syncbusinesscentral, \r\n        CASE\r\n            WHEN lower(crm.veb_sync_ee::text) = 'true'::text THEN true\r\n            ELSE false\r\n        END AS crm_syncterra, regexp_replace(COALESCE(crm.veb_vatnumber, ''::character varying)::text, '[^a-z,0-9]*'::text, ''::text, 1, 'i'::text) AS crm_btwnr, \r\n        CASE\r\n            WHEN lower(crm.veb_vatliable::text) = 'true'::text THEN true\r\n            ELSE false\r\n        END AS crm_btwplichtig, \r\n        btrim((btrim((COALESCE(crm.address1_line1, ''::character varying)::text || ' '::text) || COALESCE(crm.address1_line2, ''::character varying)::text) || ' '::text) || btrim((COALESCE(crm.veb_address1_housenumber, ''::character varying)::text || ' '::text) || COALESCE(crm.veb_address1_busnumber::character varying, ''::character varying)::text)) AS crm_adres, \r\n        COALESCE(crm_c.veb_postalcode::character varying, ''::character varying) AS crm_postcode, \r\n        COALESCE(crm_c.veb_name, ''::character varying) AS crm_stad, \r\n        COALESCE(crm_p.veb_name, ''::character varying) AS crm_provincie, \r\n        COALESCE(crm_l.veb_name, ''::character varying) AS crm_land, \r\n        COALESCE(crm_l.veb_iso2, ''::character varying) AS crm_land_iso2, \r\n        COALESCE(crm_l.veb_iso3, ''::character varying) AS crm_land_iso3, \r\n        COALESCE(crm_s.veb_sectorname, ''::character varying) AS crm_sectorname, \r\n        COALESCE(crm.veb_ovonumber, ''::character varying) AS crm_ovonr, \r\n        COALESCE(crm.veb_enterprisenumber, regexp_replace(crm.veb_vatnumber::text, '[^0-9]*'::text, ''::text)::character varying, ''::character varying) AS crm_kbonr\r\n   FROM {{ ref('010_dyn_accounts') }} crm\r\n   LEFT JOIN {{ ref('010_dyn_veb_city') }} crm_c ON crm_c.veb_cityid::text = crm._veb_address1_cityid_value::text\r\n   LEFT JOIN {{ ref('010_dyn_veb_province') }} crm_p ON crm_p.veb_provinceid::text = crm._veb_address1_provinceid_value::text\r\n   LEFT JOIN {{ ref('010_dyn_veb_country') }} crm_l ON crm_l.veb_countryid::text = crm._veb_address1_countryid_value::text\r\n   LEFT JOIN {{ source('ingest_dynamics', 'veb_sector') }} crm_s ON crm_s.veb_sector = crm.veb_sector",
#    'language': 'sql',
#    'refs': [['010_dyn_accounts'],
#     ['010_dyn_veb_city'],
#     ['010_dyn_veb_province'],
#     ['010_dyn_veb_country']],
#    'sources': [['ingest_dynamics', 'veb_sector']],
#    'metrics': [],
#    'depends_on': {'macros': [],
#     'nodes': ['source.VEB_trans_veb.ingest_dynamics.veb_sector',
#      'model.VEB_trans_veb.010_dyn_accounts',
#      'model.VEB_trans_veb.010_dyn_veb_city',
#      'model.VEB_trans_veb.010_dyn_veb_province',
#      'model.VEB_trans_veb.010_dyn_veb_country']},
#    'compiled_path': None},
#   'model.VEB_trans_veb.010_dyn_veb_country': {'database': 'terdwh',
#    'schema': 'horsum',
#    'name': '010_dyn_veb_country',
#    'resource_type': 'model',
#    'package_name': 'VEB_trans_veb',
#    'path': 'archive/010_dyn_veb_country.sql',
#    'original_file_path': 'models/archive/010_dyn_veb_country.sql',
#    'unique_id': 'model.VEB_trans_veb.010_dyn_veb_country',
#    'fqn': ['VEB_trans_veb', 'archive', '010_dyn_veb_country'],
#    'alias': '010_dyn_veb_country',
#    'checksum': {'name': 'sha256',
#     'checksum': 'cd5f45262daf03665b87b595c815c8bce79ef06dd1a72c9453026661883ab242'},
#    'config': {'enabled': True,
#     'alias': None,
#     'schema': None,
#     'database': None,
#     'tags': [],
#     'meta': {},
#     'materialized': 'table',
#     'incremental_strategy': None,
#     'persist_docs': {},
#     'quoting': {},
#     'column_types': {},
#     'full_refresh': None,
#     'unique_key': None,
#     'on_schema_change': 'ignore',
#     'grants': {},
#     'packages': [],
#     'docs': {'show': True, 'node_color': None},
#     'post-hook': [],
#     'pre-hook': []},
#    'tags': [],
#    'description': '',
#    'columns': {},
#    'meta': {},
#    'docs': {'show': True, 'node_color': None},
#    'patch_path': None,
#    'build_path': None,
#    'deferred': False,
#    'unrendered_config': {'materialized': 'table'},
#    'created_at': 1708664431.5111668,
#    'relation_name': '"terdwh"."horsum"."010_dyn_veb_country"',
#    'raw_code': '{{ config(materialized=\'table\') }}\r\nselect *, \r\n"$path" source_file ,\r\nto_timestamp(substring("$path",46,14),\'YYYYMMDDHH24MISS\') utc_processing_date \r\nfrom {{source(\'ingest_dynamics\', \'veb_country\') }}\r\nwhere utc_processing_date in\r\n\t(\r\n\tselect max(to_timestamp(substring("$path",46,14),\'YYYYMMDDHH24MISS\')) last_processing_date\r\n\tfrom {{ source(\'ingest_dynamics\', \'veb_country\') }}\r\n\t)',
#    'language': 'sql',
#    'refs': [],
#    'sources': [['ingest_dynamics', 'veb_country']],
#    'metrics': [],
#    'depends_on': {'macros': [],
#     'nodes': ['source.VEB_trans_veb.ingest_dynamics.veb_country']},
#    'compiled_path': None},
#   'model.VEB_trans_veb.010_dyn_accounts': {'database': 'terdwh',
#    'schema': 'horsum',
#    'name': '010_dyn_accounts',
#    'resource_type': 'model',
#    'package_name': 'VEB_trans_veb',
#    'path': 'archive/010_dyn_accounts.sql',
#    'original_file_path': 'models/archive/010_dyn_accounts.sql',
#    'unique_id': 'model.VEB_trans_veb.010_dyn_accounts',
#    'fqn': ['VEB_trans_veb', 'archive', '010_dyn_accounts'],
#    'alias': '010_dyn_accounts',
#    'checksum': {'name': 'sha256',
#     'checksum': '4f470c09b49df40cc2d78523597ee69fd462112a8c6f771900c0dedd92420e9f'},
#    'config': {'enabled': True,
#     'alias': None,
#     'schema': None,
#     'database': None,
#     'tags': [],
#     'meta': {},
#     'materialized': 'table',
#     'incremental_strategy': None,
#     'persist_docs': {},
#     'quoting': {},
#     'column_types': {},
#     'full_refresh': None,
#     'unique_key': None,
#     'on_schema_change': 'ignore',
#     'grants': {},
#     'packages': [],
#     'docs': {'show': True, 'node_color': None},
#     'dist': 'accountnumber',
#     'post-hook': [],
#     'pre-hook': []},
#    'tags': [],
#    'description': '',
#    'columns': {},
#    'meta': {},
#    'docs': {'show': True, 'node_color': None},
#    'patch_path': None,
#    'build_path': None,
#    'deferred': False,
#    'unrendered_config': {'materialized': 'table', 'dist': 'accountnumber'},
#    'created_at': 1708664431.513655,
#    'relation_name': '"terdwh"."horsum"."010_dyn_accounts"',
#    'raw_code': '{{ config(materialized=\'table\', dist=\'accountnumber\') }}\r\nselect \r\netag,\r\n\taccountid,\r\n\t"_createdby_value",\r\n\t"_createdbyexternalparty_value",\r\n\t"_createdonbehalfby_value",\r\n\t"_defaultpricelevelid_value",\r\n\t"_masterid_value",\r\n\t"_modifiedby_value",\r\n\t"_modifiedbyexternalparty_value",\r\n\t"_modifiedonbehalfby_value",\r\n\t"_msdyn_salesaccelerationinsightid_value",\r\n\t"_msdyn_segmentid_value",\r\n\t"_originatingleadid_value",\r\n\t"_ownerid_value",\r\n\t"_owningbusinessunit_value",\r\n\t"_owningteam_value",\r\n\t"_owninguser_value",\r\n\t"_parentaccountid_value",\r\n\t"_preferredequipmentid_value",\r\n\t"_preferredserviceid_value",\r\n\t"_preferredsystemuserid_value",\r\n\t"_primarycontactid_value",\r\n\t"_slaid_value",\r\n\t"_slainvokedid_value",\r\n\t"_territoryid_value",\r\n\t"_transactioncurrencyid_value",\r\n\t"_veb_address1_cityid_value",\r\n\t"_veb_address1_countryid_value",\r\n\t"_veb_address1_provinceid_value",\r\n\t"_veb_address2_cityid_value",\r\n\t"_veb_address2_countryid_value",\r\n\t"_veb_address2_provinceid_value",\r\n\t"_veb_nacecodeid_value",\r\n\t"_veb_primarycontact_ee_value",\r\n\t"_veb_primarycontact_el_value",\r\n\t"_veb_spoc_ee_value",\r\n\t"_veb_spoc_el_value",\r\n\taccountcategorycode,\r\n\taccountclassificationcode,\r\n\taccountnumber,\r\n\taccountratingcode,\r\n\taddress1_addressid,\r\n\taddress1_addresstypecode,\r\n\taddress1_city,\r\n\taddress1_composite,\r\n\taddress1_country,\r\n\taddress1_county,\r\n\taddress1_fax,\r\n\taddress1_freighttermscode,\r\n\taddress1_latitude,\r\n\taddress1_line1,\r\n\taddress1_line2,\r\n\taddress1_line3,\r\n\taddress1_longitude,\r\n\taddress1_name,\r\n\taddress1_postalcode,\r\n\taddress1_postofficebox,\r\n\taddress1_primarycontactname,\r\n\taddress1_shippingmethodcode,\r\n\taddress1_stateorprovince,\r\n\taddress1_telephone1,\r\n\taddress1_telephone2,\r\n\taddress1_telephone3,\r\n\taddress1_upszone,\r\n\taddress1_utcoffset,\r\n\taddress2_addressid,\r\n\taddress2_addresstypecode,\r\n\taddress2_city,\r\n\taddress2_composite,\r\n\taddress2_country,\r\n\taddress2_county,\r\n\taddress2_fax,\r\n\taddress2_freighttermscode,\r\n\taddress2_latitude,\r\n\taddress2_line1,\r\n\taddress2_line2,\r\n\taddress2_line3,\r\n\taddress2_longitude,\r\n\taddress2_name,\r\n\taddress2_postalcode,\r\n\taddress2_postofficebox,\r\n\taddress2_primarycontactname,\r\n\taddress2_shippingmethodcode,\r\n\taddress2_stateorprovince,\r\n\taddress2_telephone1,\r\n\taddress2_telephone2,\r\n\taddress2_telephone3,\r\n\taddress2_upszone,\r\n\taddress2_utcoffset,\r\n\taging30,\r\n\taging30_base,\r\n\taging60,\r\n\taging60_base,\r\n\taging90,\r\n\taging90_base,\r\n\tbusinesstypecode,\r\n\tcase when date_part(hour,createdon)<12 then dateadd(month,-1,createdon)\r\n\telse dateadd(month,-1,dateadd(day,-1,createdon)) end createdon,\r\n\tcreditlimit,\r\n\tcreditlimit_base,\r\n\tcreditonhold,\r\n\tcustomersizecode,\r\n\tcustomertypecode,\r\n\tdescription,\r\n\tdonotbulkemail,\r\n\tdonotbulkpostalmail,\r\n\tdonotemail,\r\n\tdonotfax,\r\n\tdonotphone,\r\n\tdonotpostalmail,\r\n\tdonotsendmm,\r\n\temailaddress1,\r\n\temailaddress2,\r\n\temailaddress3,\r\n\tentityimage,\r\n\tentityimage_timestamp,\r\n\tentityimage_url,\r\n\tentityimageid,\r\n\texchangerate,\r\n\tfax,\r\n\tfollowemail,\r\n\tftpsiteurl,\r\n\timportsequencenumber,\r\n\tindustrycode,\r\n\tcase when date_part(hour,lastonholdtime)<12 then dateadd(month,-1,lastonholdtime)\r\n\telse dateadd(month,-1,dateadd(day,-1,lastonholdtime)) end lastonholdtime,\r\n\tcase when date_part(hour,lastusedincampaign)<12 then dateadd(month,-1,lastusedincampaign)\r\n\telse dateadd(month,-1,dateadd(day,-1,lastusedincampaign)) end lastusedincampaign,\r\n\tmarketcap,\r\n\tmarketcap_base,\r\n\tmarketingonly,\r\n\tmerged,\r\n\tcase when date_part(hour,modifiedon)<12 then dateadd(month,-1,modifiedon)\r\n\telse dateadd(month,-1,dateadd(day,-1,modifiedon)) end modifiedon,\r\n\tmsdyn_gdproptout,\r\n\t"name",\r\n\tnumberofemployees,\r\n\tonholdti ...
#    'language': 'sql',
#    'refs': [],
#    'sources': [['ingest_dynamics', 'accounts']],
#    'metrics': [],
#    'depends_on': {'macros': [],
#     'nodes': ['source.VEB_trans_veb.ingest_dynamics.accounts']},
#    'compiled_path': None},
#   'model.VEB_trans_veb.020_ter_organisations': {'database': 'terdwh',
#    'schema': 'horsum',
#    'name': '020_ter_organisations',
#    'resource_type': 'model',
#    'package_name': 'VEB_trans_veb',
#    'path': 'archive/020_ter_organisations.sql',
#    'original_file_path': 'models/archive/020_ter_organisations.sql',
#    'unique_id': 'model.VEB_trans_veb.020_ter_organisations',
#    'fqn': ['VEB_trans_veb', 'archive', '020_ter_organisations'],
#    'alias': '020_ter_organisations',
#    'checksum': {'name': 'sha256',
#     'checksum': '8c722874dd5709b6331b2a6b469e559beb1def8934d97fefd122da0fd05b2930'},
#    'config': {'enabled': True,
#     'alias': None,
#     'schema': None,
#     'database': None,
#     'tags': [],
#     'meta': {},
#     'materialized': 'table',
#     'incremental_strategy': None,
#     'persist_docs': {},
#     'quoting': {},
#     'column_types': {},
#     'full_refresh': None,
#     'unique_key': None,
#     'on_schema_change': 'ignore',
#     'grants': {},
#     'packages': [],
#     'docs': {'show': True, 'node_color': None},
#     'dist': 't_klantnummer',
#     'post-hook': [],
#     'pre-hook': []},
#    'tags': [],
#    'description': '',
#    'columns': {},
#    'meta': {},
#    'docs': {'show': True, 'node_color': None},
#    'patch_path': None,
#    'build_path': None,
#    'deferred': False,
#    'unrendered_config': {'materialized': 'table', 'dist': 't_klantnummer'},
#    'created_at': 1708664431.516306,
#    'relation_name': '"terdwh"."horsum"."020_ter_organisations"',
#    'raw_code': "{{ config(materialized='table', dist='t_klantnummer') }}\r\nSELECT \r\n    o.crmaccountnumber::integer AS t_klantnummer, \r\n    o.name AS t_klantnaam, \r\n    regexp_replace(o.kbonumber::text, '[^0-9]*'::text, ''::text) AS t_kbonr, \r\n    COALESCE(o.category, ''::character varying) AS t_sector, \r\n    COALESCE(o.ovonumber, ''::character varying) AS t_ovonr\r\nFROM {{source('ingest_terra','organisationlist')}} o",
#    'language': 'sql',
#    'refs': [],
#    'sources': [['ingest_terra', 'organisationlist']],
#    'metrics': [],
#    'depends_on': {'macros': [],
#     'nodes': ['source.VEB_trans_veb.ingest_terra.organisationlist']},
#    'compiled_path': None},
#   'model.VEB_trans_veb.020_lynx_rel': {'database': 'terdwh',
#    'schema': 'horsum',
#    'name': '020_lynx_rel',
#    'resource_type': 'model',
#    'package_name': 'VEB_trans_veb',
#    'path': 'archive/020_lynx_rel.sql',
#    'original_file_path': 'models/archive/020_lynx_rel.sql',
#    'unique_id': 'model.VEB_trans_veb.020_lynx_rel',
#    'fqn': ['VEB_trans_veb', 'archive', '020_lynx_rel'],
#    'alias': '020_lynx_rel',
#    'checksum': {'name': 'sha256',
#     'checksum': '6857c983406f51971715a82b5e4d2f5d78fb7a5f6983d4d5e10ce44ccd54dda7'},
#    'config': {'enabled': True,
#     'alias': None,
#     'schema': None,
#     'database': None,
#     'tags': [],
#     'meta': {},
#     'materialized': 'table',
#     'incremental_strategy': None,
#     'persist_docs': {},
#     'quoting': {},
#     'column_types': {},
#     'full_refresh': None,
#     'unique_key': None,
#     'on_schema_change': 'ignore',
#     'grants': {},
#     'packages': [],
#     'docs': {'show': True, 'node_color': None},
#     'dist': 'lynx_klantnummer',
#     'post-hook': [],
#     'pre-hook': []},
#    'tags': [],
#    'description': '',
#    'columns': {},
#    'meta': {},
#    'docs': {'show': True, 'node_color': None},
#    'patch_path': None,
#    'build_path': None,
#    'deferred': False,
#    'unrendered_config': {'materialized': 'table', 'dist': 'lynx_klantnummer'},
#    'created_at': 1708664431.5187583,
#    'relation_name': '"terdwh"."horsum"."020_lynx_rel"',
#    'raw_code': "{{ config(materialized='table', dist='lynx_klantnummer') }}\r\nSELECT \r\n    r.reference AS lynx_klantnummer, \r\n    r.name AS lynx_klantnaam, \r\n    regexp_replace(COALESCE(r.vatnumber, ''::character varying)::text, '[^a-z,0-9]*'::text, ''::text, 1, 'i'::text) AS lynx_btwnr, \r\n    regexp_replace(COALESCE(r.companynumber, ''::character varying)::text, '[^a-z,0-9]*'::text, ''::text, 1, 'i'::text) AS lynx_kbonr, \r\n    btrim((COALESCE(r.street, ''::character varying)::text || ' '::text) || COALESCE(r.streetnumber, ''::character varying)::text) AS lynx_adres, \r\n    COALESCE(c.zipcode, ''::character varying) AS lynx_postcode, \r\n    COALESCE(c.name, ''::character varying) AS lynx_stad, \r\n    CASE\r\n        WHEN COALESCE(c.country, ''::character varying)::text = 'BE'::text THEN 'België'::character varying\r\n        ELSE COALESCE(c.country, ''::character varying)\r\n    END AS lynx_land\r\nFROM {{source('ingest','cogenius_rel')}} r\r\n   LEFT JOIN {{source('ingest','cogenius_city')}} c ON c.id = r.city_id",
#    'language': 'sql',
#    'refs': [],
#    'sources': [['ingest', 'cogenius_city'], ['ingest', 'cogenius_rel']],
#    'metrics': [],
#    'depends_on': {'macros': [],
#     'nodes': ['source.VEB_trans_veb.ingest.cogenius_city',
#      'source.VEB_trans_veb.ingest.cogenius_rel']},
#    'compiled_path': None},
#   'model.VEB_trans_veb.survey_monkey_list': {'database': 'terdwh',
#    'schema': 'horsum',
#    'name': 'survey_monkey_list',
#    'resource_type': 'model',
#    'package_name': 'VEB_trans_veb',
#    'path': 'marketing/survey_monkey_list.sql',
#    'original_file_path': 'models/marketing/survey_monkey_list.sql',
#    'unique_id': 'model.VEB_trans_veb.survey_monkey_list',
#    'fqn': ['VEB_trans_veb', 'marketing', 'survey_monkey_list'],
#    'alias': 'survey_monkey_list',
#    'checksum': {'name': 'sha256',
#     'checksum': '09be21b5ec0afa292ec52214d56c24fd80477ff5e33a925edb5fe121be5509f8'},
#    'config': {'enabled': True,
#     'alias': None,
#     'schema': None,
#     'database': None,
#     'tags': [],
#     'meta': {},
#     'materialized': 'table',
#     'incremental_strategy': None,
#     'persist_docs': {},
#     'quoting': {},
#     'column_types': {},
#     'full_refresh': None,
#     'unique_key': None,
#     'on_schema_change': 'ignore',
#     'grants': {},
#     'packages': [],
#     'docs': {'show': True, 'node_color': None},
#     'post-hook': [],
#     'pre-hook': []},
#    'tags': [],
#    'description': '',
#    'columns': {},
#    'meta': {},
#    'docs': {'show': True, 'node_color': None},
#    'patch_path': None,
#    'build_path': None,
#    'deferred': False,
#    'unrendered_config': {'materialized': 'table'},
#    'created_at': 1708664431.5211935,
#    'relation_name': '"terdwh"."horsum"."survey_monkey_list"',
#    'raw_code': 'select \r\n    "interval",\r\n\tsurvey,\r\n\tfriendlyname,\r\n\t"name",\r\n\tveb_owner,\r\n\tspoc_email,\r\n\tspoc_firstname,\r\n\tspoc_lastname,\r\n\tops_email,\r\n\tops_firstname,\r\n\tops_lastname,\r\n    \'\' as productname,\r\n\tsnapshot_month \r\nfrom {{ref(\'survey_lev_1_new_customers\')}}\r\nunion all \r\nselect \r\n    "interval",\r\n\tsurvey,\r\n\tfriendlyname,\r\n\t"name",\r\n\tveb_owner,\r\n\tspoc_email,\r\n\tspoc_firstname,\r\n\tspoc_lastname,\r\n\tops_email,\r\n\tops_firstname,\r\n\tops_lastname,\r\n    \'\' as productname,\r\n\tsnapshot_month \r\nfrom {{ref(\'survey_lev_2_second_invoice\')}}\r\nunion all \r\nselect \r\n    "interval",\r\n\tsurvey,\r\n\tfriendlyname,\r\n\t"name",\r\n\tveb_owner,\r\n\tspoc_email,\r\n\tspoc_firstname,\r\n\tspoc_lastname,\r\n\tops_email,\r\n\tops_firstname,\r\n\tops_lastname,\r\n    \'\' as productname,\r\n\tsnapshot_month \r\nfrom {{ ref(\'survey_lev_3_existing_customers\') }}\r\nunion all \r\nselect \r\n    "interval",\r\n\tsurvey,\r\n\tfriendlyname,\r\n\t"name",\r\n\tveb_owner,\r\n\tspoc_email,\r\n\tspoc_firstname,\r\n\tspoc_lastname,\r\n\tops_email,\r\n\tops_firstname,\r\n\tops_lastname,\r\n    \'\' as productname,\r\n\tsnapshot_month \r\nfrom {{ref(\'survey_lev_4_complaints\')}}\r\nunion all \r\nselect \r\n    "interval",\r\n\tsurvey,\r\n\tfriendlyname,\r\n\t"name",\r\n\tveb_owner,\r\n\tspoc_email,\r\n\tspoc_firstname,\r\n\tspoc_lastname,\r\n\tops_email,\r\n\tops_firstname,\r\n\tops_lastname,\r\n    \'\' as productname,\r\n\tsnapshot_month \r\nfrom {{ref(\'survey_lev_5_smr\')}}\r\nunion all \r\nselect \r\n    "interval",\r\n\tsurvey,\r\n\tfriendlyname,\r\n\t"name",\r\n\tveb_owner,\r\n\tspoc_email,\r\n\tspoc_firstname,\r\n\tspoc_lastname,\r\n\tops_email,\r\n\tops_firstname,\r\n\tops_lastname,\r\n    \'\' as productname,\r\n\tsnapshot_month \r\nfrom {{ ref(\'survey_lev_6_injection\') }}\r\nunion all \r\nselect \r\n    "interval",\r\n\tsurvey,\r\n\tfriendlyname,\r\n\t"name",\r\n\tveb_owner,\r\n\tspoc_email,\r\n\tspoc_firstname,\r\n\tspoc_lastname,\r\n\tops_email,\r\n\tops_firstname,\r\n\tops_lastname,\r\n    productname,\r\n\tsnapshot_month \r\nfrom {{ ref(\'survey_ee_1_new_requests\') }}\r\nunion all \r\nselect \r\n    "interval",\r\n\tsurvey,\r\n\tfriendlyname,\r\n\t"name",\r\n\tveb_owner,\r\n\tspoc_email,\r\n\tspoc_firstname,\r\n\tspoc_lastname,\r\n\tops_email,\r\n\tops_firstname,\r\n\tops_lastname,\r\n    productname,\r\n\tsnapshot_month \r\nfrom {{ ref(\'survey_ee_2_start_execution\') }}\r\nunion all \r\nselect \r\n    "interval",\r\n\tsurvey,\r\n\tfriendlyname,\r\n\t"name",\r\n\tveb_owner,\r\n\tspoc_email,\r\n\tspoc_firstname,\r\n\tspoc_lastname,\r\n\tops_email,\r\n\tops_firstname,\r\n\tops_lastname,\r\n    \'\' as productname,\r\n\tsnapshot_month \r\nfrom {{ ref(\'survey_ee_3_complaints\') }}\r\nunion all \r\nselect \r\n    "interval",\r\n\tsurvey,\r\n\tfriendlyname,\r\n\t"name",\r\n\tveb_owner,\r\n\tspoc_email,\r\n\tspoc_firstname,\r\n\tspoc_lastname,\r\n\tops_email,\r\n\tops_firstname,\r\n\tops_lastname,\r\n    productname,\r\n\tsnapshot_month \r\nfrom{{ ref(\'survey_ee_4_finish_execution\') }}',
#    'language': 'sql',
#    'refs': [['survey_lev_1_new_customers'],
#     ['survey_lev_2_second_invoice'],
#     ['survey_lev_3_existing_customers'],
#     ['survey_lev_4_complaints'],
#     ['survey_lev_5_smr'],
#     ['survey_lev_6_injection'],
#     ['survey_ee_1_new_requests'],
#     ['survey_ee_2_start_execution'],
#     ['survey_ee_3_complaints'],
#     ['survey_ee_4_finish_execution']],
#    'sources': [],
#    'metrics': [],
#    'depends_on': {'macros': [],
#     'nodes': ['model.VEB_trans_veb.survey_lev_1_new_customers',
#      'model.VEB_trans_veb.survey_lev_2_second_invoice',
#      'model.VEB_trans_veb.survey_lev_3_existing_customers',
#      'model.VEB_trans_veb.survey_lev_4_complaints',
#      'model.VEB_trans_veb.survey_lev_5_smr',
#      'model.VEB_trans_veb.survey_lev_6_injection',
#      'model.VEB_trans_veb.survey_ee_1_new_requests',
#      'model.VEB_trans_veb.survey_ee_2_start_execution',
#      'model.VEB_trans_veb.survey_ee_3_complaints',
#      'model.VEB_trans_veb.survey_ee_4_finish_execution']},
#    'compiled_path': None},
#   'model.VEB_trans_veb.survey_lev_2_second_invoice': {'database': 'terdwh',
#    'schema': 'horsum',
#    'name': 'survey_lev_2_second_invoice',
#    'resource_type': 'model',
#    'package_name': 'VEB_trans_veb',
#    'path': 'marketing/surveys/monthly/survey_lev_2_second_invoice.sql',
#    'original_file_path': 'models/marketing/surveys/monthly/survey_lev_2_second_invoice.sql',
#    'unique_id': 'model.VEB_trans_veb.survey_lev_2_second_invoice',
#    'fqn': ['VEB_trans_veb',
#     'marketing',
#     'surveys',
#     'monthly',
#     'survey_lev_2_second_invoice'],
#    'alias': 'survey_lev_2_second_invoice',
#    'checksum': {'name': 'sha256',
#     'checksum': 'b8be747b750a5904a86e8754f86be007c6e4bc2c88d5877fa11b57796f68a007'},
#    'config': {'enabled': True,
#     'alias': None,
#     'schema': None,
#     'database': None,
#     'tags': [],
#     'meta': {},
#     'materialized': 'incremental',
#     'incremental_strategy': 'delete+insert',
#     'persist_docs': {},
#     'quoting': {},
#     'column_types': {},
#     'full_refresh': None,
#     'unique_key': 'snapshot_month',
#     'on_schema_change': 'ignore',
#     'grants': {},
#     'packages': [],
#     'docs': {'show': True, 'node_color': None},
#     'transient': False,
#     'post-hook': [],
#     'pre-hook': []},
#    'tags': [],
#    'description': '',
#    'columns': {},
#    'meta': {},
#    'docs': {'show': True, 'node_color': None},
#    'patch_path': None,
#    'build_path': None,
#    'deferred': False,
#    'unrendered_config': {'materialized': 'incremental',
#     'transient': False,
#     'incremental_strategy': 'delete+insert',
#     'unique_key': 'snapshot_month'},
#    'created_at': 1708664431.5258737,
#    'relation_name': '"terdwh"."horsum"."survey_lev_2_second_invoice"',
#    'raw_code': '{{\r\n    config(\r\n        materialized=\'incremental\',\r\n        transient=false,\r\n        incremental_strategy=\'delete+insert\',\r\n        unique_key=\'snapshot_month\'\r\n    )\r\n}}\r\nwith sub2 as(\r\n\tselect \r\n\t\trel.friendlyname, \r\n\t\tcount(distinct i.invoicedate) \r\n\tfrom ingest.cogenius_inv i\r\n\t\tjoin ingest.cogenius_inv_stats stat\r\n\t\ton(stat.inv_id=i.id)\r\n\t\tjoin ingest.cogenius_pr pr\r\n\t\ton(stat.pr_id = pr.id)\r\n\t\tjoin ingest.cogenius_pr_group prg\r\n\t\ton(pr.pr_group_id=prg.id)\r\n\t\tjoin ingest.cogenius_ag\tag\t\t\t\t\r\n\t\ton (ag.id = pr.ag_current_id)\r\n\t\tjoin ingest.cogenius_rc\trc\t\t\t\t\r\n\t\ton (ag.rc_id = rc.id)\r\n\t\tjoin ingest.cogenius_rel rel\t\t\t\t\t\r\n\t\ton (rc.rel_id = rel.id)\r\n\twhere \r\n\t\tinvoicedate < date_trunc(\'month\',current_date)\r\n\tgroup by rel.friendlyname\r\n\thaving count(distinct i.invoicedate)=2\r\n)\r\n,sub3 as(\r\n\tselect \r\n\t\trel.friendlyname,\r\n\t\ti.invoicedate,\r\n\t\trank() over\r\n\t\t(partition by rel.friendlyname\r\n\t\torder by i.invoicedate desc) as rank\r\n\tfrom ingest.cogenius_inv i\r\n\t\tjoin ingest.cogenius_inv_stats stat\r\n\t\ton(stat.inv_id=i.id)\r\n\t\tjoin ingest.cogenius_pr pr\r\n\t\ton(stat.pr_id = pr.id)\r\n\t\tjoin ingest.cogenius_pr_group prg\r\n\t\ton(pr.pr_group_id=prg.id)\r\n\t\tjoin ingest.cogenius_ag\tag\t\t\t\t\r\n\t\ton (ag.id = pr.ag_current_id)\r\n\t\tjoin ingest.cogenius_rc\trc\t\t\t\t\r\n\t\ton (ag.rc_id = rc.id)\r\n\t\tjoin ingest.cogenius_rel rel\t\t\t\t\t\r\n\t\ton (rc.rel_id = rel.id)\r\n\t\tjoin sub2\r\n\t\ton(rel.friendlyname=sub2.friendlyname)\r\n    where\r\n\t\tinvoicedate >= date_add(\'month\',-1,date_trunc(\'month\',current_date)) \r\n\t\tand \r\n        invoicedate < date_trunc(\'month\',current_date)\r\n)\r\n,sub4 as(\r\n\tselect \r\n\t\tdistinct friendlyname ,\r\n        invoicedate\r\n\tfrom\r\n\t\tsub3\r\n\twhere \r\n\t\trank=1\r\n\t\tand invoicedate >= date_add(\'month\',-1,date_trunc(\'month\',current_date)) \r\n\t\tand invoicedate < date_trunc(\'month\',current_date)\r\n)\r\nselect \r\n\tdistinct\r\n    \'maandelijks\' as "interval",\r\n    \'LEV 2 tweede factuur\' as survey,\r\n\ta.veb_shortname as friendlyname,\r\n\ta.name,\r\n\ta."_ownerid_value_display" as veb_owner,\r\n\tspoc.emailaddress1 as spoc_email,\r\n    spoc.firstname as spoc_firstname,\r\n    spoc.lastname as spoc_lastname,\r\n    co.emailaddress1 as ops_email,\r\n    co.firstname as ops_firstname,\r\n    co.lastname as ops_lastname,\r\n    date_add(\'month\',1,date_trunc(\'month\',sub4.invoicedate))::date as snapshot_month\r\nfrom  ingest.crm_accounts a\r\nleft join ingest.crm_contacts co\r\non(a."_veb_primarycontact_el_value"=co.contactid)\r\nleft join ingest.crm_contacts spoc\r\non(a."_veb_spoc_el_value"=spoc.contactid)\r\njoin sub4\r\non(sub4.friendlyname=a.veb_shortname)\r\n{% if is_incremental() %}\r\n\t--only load row if snapshot doesn\'t exist yet\r\nWHERE snapshot_month NOT IN (SELECT DISTINCT snapshot_month FROM {{ this }})\r\n{% endif %}',
#    'language': 'sql',
#    'refs': [],
#    'sources': [],
#    'metrics': [],
#    'depends_on': {'macros': ['macro.dbt.is_incremental'], 'nodes': []},
#    'compiled_path': None},
#   'model.VEB_trans_veb.survey_ee_3_complaints': {'database': 'terdwh',
#    'schema': 'horsum',
#    'name': 'survey_ee_3_complaints',
#    'resource_type': 'model',
#    'package_name': 'VEB_trans_veb',
#    'path': 'marketing/surveys/monthly/survey_ee_3_complaints.sql',
#    'original_file_path': 'models/marketing/surveys/monthly/survey_ee_3_complaints.sql',
#    'unique_id': 'model.VEB_trans_veb.survey_ee_3_complaints',
#    'fqn': ['VEB_trans_veb',
#     'marketing',
#     'surveys',
#     'monthly',
#     'survey_ee_3_complaints'],
#    'alias': 'survey_ee_3_complaints',
#    'checksum': {'name': 'sha256',
#     'checksum': 'fc193a338e9d95c2c9918bc7239cd47f6d948b78c459aa674ea400f97458847c'},
#    'config': {'enabled': True,
#     'alias': None,
#     'schema': None,
#     'database': None,
#     'tags': [],
#     'meta': {},
#     'materialized': 'incremental',
#     'incremental_strategy': 'delete+insert',
#     'persist_docs': {},
#     'quoting': {},
#     'column_types': {},
#     'full_refresh': None,
#     'unique_key': 'snapshot_month',
#     'on_schema_change': 'ignore',
#     'grants': {},
#     'packages': [],
#     'docs': {'show': True, 'node_color': None},
#     'transient': False,
#     'post-hook': [],
#     'pre-hook': []},
#    'tags': [],
#    'description': '',
#    'columns': {},
#    'meta': {},
#    'docs': {'show': True, 'node_color': None},
#    'patch_path': None,
#    'build_path': None,
#    'deferred': False,
#    'unrendered_config': {'materialized': 'incremental',
#     'transient': False,
#     'incremental_strategy': 'delete+insert',
#     'unique_key': 'snapshot_month'},
#    'created_at': 1708664431.5381227,
#    'relation_name': '"terdwh"."horsum"."survey_ee_3_complaints"',
#    'raw_code': '{{\r\n    config(\r\n        materialized=\'incremental\',\r\n        transient=false,\r\n        incremental_strategy=\'delete+insert\',\r\n        unique_key=\'snapshot_month\'\r\n    )\r\n}}\r\nselect \r\n    \'maandelijks\' as "interval",\r\n    \'EE 3 Freshdesk klachten\' as survey,\r\n    co."name"  as friendlyname,\r\n    co."name" as name,\r\n    ag.agentname veb_owner,\r\n    lower(ti.email) as spoc_email,\r\n    left(con."name",CHARINDEX(\' \', con."name" )) as spoc_firstname ,\r\n    substring (con."name" from CHARINDEX(\' \', con."name" )) as spoc_lastname,\r\n    \'\' as ops_email,\r\n    \'\' as ops_firstname,\r\n    \'\' as ops_lastname,\r\n    date_add(\'month\',1,date_trunc(\'month\',resolvedat))::date as snapshot_month\r\nfrom ingest.freshdesk_tickets ti\r\nleft join ingest.freshdesk_companies co\r\non(ti.companyid=co.id)\r\nleft join ingest.freshdesk_contacts con\r\non(ti.requesterid=con.id)\r\nleft join ingest.freshdesk_groups gr\r\non(ti.groupid=gr.id)\r\nleft join ingest.freshdesk_agents ag\r\non(ti.responderid=ag.id)\r\nwhere \r\n    type=\'Klacht\' \r\n\tand gr.name=\'Efficiëntie\'\r\n\tand spoc_email not like \'%@veb.be\'\r\n\tand resolvedat  >= date_add(\'month\',-1,date_trunc(\'month\',current_date))\r\n    and resolvedat< date_trunc(\'month\',current_date)\r\n{% if is_incremental() %}\r\n--only load row if snapshot doesn\'t exist yet\r\nAND snapshot_month NOT IN (SELECT DISTINCT snapshot_month FROM {{ this }})\r\n{% endif %}',
#    'language': 'sql',
#    'refs': [],
#    'sources': [],
#    'metrics': [],
#    'depends_on': {'macros': ['macro.dbt.is_incremental'], 'nodes': []},
#    'compiled_path': None},
#   'model.VEB_trans_veb.survey_ee_2_start_execution': {'database': 'terdwh',
#    'schema': 'horsum',
#    'name': 'survey_ee_2_start_execution',
#    'resource_type': 'model',
#    'package_name': 'VEB_trans_veb',
#    'path': 'marketing/surveys/monthly/survey_ee_2_start_execution.sql',
#    'original_file_path': 'models/marketing/surveys/monthly/survey_ee_2_start_execution.sql',
#    'unique_id': 'model.VEB_trans_veb.survey_ee_2_start_execution',
#    'fqn': ['VEB_trans_veb',
#     'marketing',
#     'surveys',
#     'monthly',
#     'survey_ee_2_start_execution'],
#    'alias': 'survey_ee_2_start_execution',
#    'checksum': {'name': 'sha256',
#     'checksum': 'f9abf70f864fd5380e5b9c65ea96e9b39f9953eafabca02a09508c8dd318df35'},
#    'config': {'enabled': True,
#     'alias': None,
#     'schema': None,
#     'database': None,
#     'tags': [],
#     'meta': {},
#     'materialized': 'incremental',
#     'incremental_strategy': 'delete+insert',
#     'persist_docs': {},
#     'quoting': {},
#     'column_types': {},
#     'full_refresh': None,
#     'unique_key': 'snapshot_month',
#     'on_schema_change': 'ignore',
#     'grants': {},
#     'packages': [],
#     'docs': {'show': True, 'node_color': None},
#     'transient': False,
#     'post-hook': [],
#     'pre-hook': []},
#    'tags': [],
#    'description': '',
#    'columns': {},
#    'meta': {},
#    'docs': {'show': True, 'node_color': None},
#    'patch_path': None,
#    'build_path': None,
#    'deferred': False,
#    'unrendered_config': {'materialized': 'incremental',
#     'transient': False,
#     'incremental_strategy': 'delete+insert',
#     'unique_key': 'snapshot_month'},
#    'created_at': 1708664431.5438201,
#    'relation_name': '"terdwh"."horsum"."survey_ee_2_start_execution"',
#    'raw_code': '{{\r\n    config(\r\n        materialized=\'incremental\',\r\n        transient=false,\r\n        incremental_strategy=\'delete+insert\',\r\n        unique_key=\'snapshot_month\'\r\n    )\r\n}}\r\nselect distinct\r\n    \'maandelijks\' as "interval",\r\n    \'EE 2 start uitvoering\' as survey,\r\n    \'\' as friendlyname,\r\n\treq.customerorganisationname as name,\r\n    inf.customercareuserfirstname +\' \'+inf.customercareuserlastname veb_owner,\r\n\tlower(inf.contactemailaddress) spoc_email ,\r\n\tinitcap(inf.contactfirstname) spoc_firstname ,\r\n\tinitcap(inf.contactlastname) spoc_lastname,\r\n    \'\' as ops_email,\r\n    \'\' as ops_firstname,\r\n    \'\' as ops_lastname,\r\n    req.productname,\r\n    date_add(\'month\',1,date_trunc(\'month\',dyn.eventdatetime))::date as snapshot_month\r\nfrom \r\n\tingest.eep_requestdynamicstatelistview dyn\r\njoin ingest.eep_requestlist req\r\non(dyn.requestid=req.id)\r\njoin ingest.eep_requestinformationitem inf\r\non(req.requestreadableid=inf.requestreadableid)\r\nwhere dyn.state in(\'Uitvoeringsfase\',\'Uitvoeringsfase opgestart\',\'Het proefcertificaat werd opgeladen\',\'Offerte geaccepteerd\')\r\nand dyn.eventdatetime  >= date_add(\'month\',-1,date_trunc(\'month\',current_date))\r\nand dyn.eventdatetime < date_trunc(\'month\',current_date)\r\n{% if is_incremental() %}\r\n\t--only load row if snapshot doesn\'t exist yet\r\nAND snapshot_month NOT IN (SELECT DISTINCT snapshot_month FROM {{ this }})\r\n{% endif %}',
#    'language': 'sql',
#    'refs': [],
#    'sources': [],
#    'metrics': [],
#    'depends_on': {'macros': ['macro.dbt.is_incremental'], 'nodes': []},
#    'compiled_path': None},
#   'model.VEB_trans_veb.survey_lev_3_existing_customers': {'database': 'terdwh',
#    'schema': 'horsum',
#    'name': 'survey_lev_3_existing_customers',
#    'resource_type': 'model',
#    'package_name': 'VEB_trans_veb',
#    'path': 'marketing/surveys/monthly/survey_lev_3_existing_customers.sql',
#    'original_file_path': 'models/marketing/surveys/monthly/survey_lev_3_existing_customers.sql',
#    'unique_id': 'model.VEB_trans_veb.survey_lev_3_existing_customers',
#    'fqn': ['VEB_trans_veb',
#     'marketing',
#     'surveys',
#     'monthly',
#     'survey_lev_3_existing_customers'],
#    'alias': 'survey_lev_3_existing_customers',
#    'checksum': {'name': 'sha256',
#     'checksum': 'fca2532fc8b5fdaabae2933c3fe2dd8b9cb3d2e59bdf7363ae058db4e0c38f02'},
#    'config': {'enabled': True,
#     'alias': None,
#     'schema': None,
#     'database': None,
#     'tags': [],
#     'meta': {},
#     'materialized': 'incremental',
#     'incremental_strategy': 'delete+insert',
#     'persist_docs': {},
#     'quoting': {},
#     'column_types': {},
#     'full_refresh': None,
#     'unique_key': 'snapshot_month',
#     'on_schema_change': 'ignore',
#     'grants': {},
#     'packages': [],
#     'docs': {'show': True, 'node_color': None},
#     'transient': False,
#     'post-hook': [],
#     'pre-hook': []},
#    'tags': [],
#    'description': '',
#    'columns': {},
#    'meta': {},
#    'docs': {'show': True, 'node_color': None},
#    'patch_path': None,
#    'build_path': None,
#    'deferred': False,
#    'unrendered_config': {'materialized': 'incremental',
#     'transient': False,
#     'incremental_strategy': 'delete+insert',
#     'unique_key': 'snapshot_month'},
#    'created_at': 1708664431.5491343,
#    'relation_name': '"terdwh"."horsum"."survey_lev_3_existing_customers"',
#    'raw_code': '{{\r\n    config(\r\n        materialized=\'incremental\',\r\n        transient=false,\r\n        incremental_strategy=\'delete+insert\',\r\n        unique_key=\'snapshot_month\'\r\n    )\r\n}}\r\nselect \r\n\tdistinct\r\n    \'maandelijks\' as "interval",\r\n    \'LEV 3 bestaande klanten\' as survey,\r\n\ta.veb_shortname as friendlyname,\r\n\ta.name,\r\n\ta."_ownerid_value_display" as veb_owner,\r\n\tspoc.emailaddress1 as spoc_email,\r\n    spoc.firstname as spoc_firstname,\r\n    spoc.lastname as spoc_lastname,\r\n    co.emailaddress1 as ops_email,\r\n    co.firstname as ops_firstname,\r\n    co.lastname as ops_lastname,\r\n    date_add(\'month\',1,date_add(\'year\',1,date_trunc(\'month\',veb_startdate)))::date snapshot_month\r\nfrom ingest.crm_veb_contracts c\r\nleft join ingest.crm_accounts a\r\non(c._veb_accountid_value=a.accountid)\r\nleft join ingest.crm_contacts co\r\non(a."_veb_primarycontact_el_value"=co.contactid)\r\nleft join ingest.crm_contacts spoc\r\non(a."_veb_spoc_el_value"=spoc.contactid)\r\nwhere \r\nveb_startdate >= date_add(\'month\',-1,date_add(\'year\',-1,date_trunc(\'month\',current_date)))\r\nand \r\nveb_startdate < date_add(\'year\',-1,date_trunc(\'month\',current_date))\r\nand \r\nveb_enddate > current_date\r\nand \r\nc.statecode_display=\'Active\'\r\nand c.statuscode_display=\'Active\'\r\nand c.veb_contractreference like \'LEV%\'\r\n{% if is_incremental() %}\r\n--only load row if snapshot doesn\'t exist yet\r\nAND snapshot_month NOT IN (SELECT DISTINCT snapshot_month FROM {{ this }})\r\n{% endif %}',
#    'language': 'sql',
#    'refs': [],
#    'sources': [],
#    'metrics': [],
#    'depends_on': {'macros': ['macro.dbt.is_incremental'], 'nodes': []},
#    'compiled_path': None},
#   'model.VEB_trans_veb.survey_ee_1_new_requests': {'database': 'terdwh',
#    'schema': 'horsum',
#    'name': 'survey_ee_1_new_requests',
#    'resource_type': 'model',
#    'package_name': 'VEB_trans_veb',
#    'path': 'marketing/surveys/monthly/survey_ee_1_new_requests.sql',
#    'original_file_path': 'models/marketing/surveys/monthly/survey_ee_1_new_requests.sql',
#    'unique_id': 'model.VEB_trans_veb.survey_ee_1_new_requests',
#    'fqn': ['VEB_trans_veb',
#     'marketing',
#     'surveys',
#     'monthly',
#     'survey_ee_1_new_requests'],
#    'alias': 'survey_ee_1_new_requests',
#    'checksum': {'name': 'sha256',
#     'checksum': 'f332ed5a10d49fed6993d9ad0ca32c1d5252edb608d867e31a10b4effb24cea5'},
#    'config': {'enabled': True,
#     'alias': None,
#     'schema': None,
#     'database': None,
#     'tags': [],
#     'meta': {},
#     'materialized': 'incremental',
#     'incremental_strategy': 'delete+insert',
#     'persist_docs': {},
#     'quoting': {},
#     'column_types': {},
#     'full_refresh': None,
#     'unique_key': 'snapshot_month',
#     'on_schema_change': 'ignore',
#     'grants': {},
#     'packages': [],
#     'docs': {'show': True, 'node_color': None},
#     'transient': False,
#     'post-hook': [],
#     'pre-hook': []},
#    'tags': [],
#    'description': '',
#    'columns': {},
#    'meta': {},
# ...
#   'model.redshift.redshift_cost': ['model.redshift.redshift_admin_queries'],
#   'model.redshift.pg_depend': ['model.redshift.redshift_admin_dependencies',
#    'model.redshift.redshift_admin_dependencies'],
#   'model.redshift.pg_namespace': ['model.redshift.redshift_admin_dependencies',
#    'model.redshift.redshift_admin_dependencies',
#    'model.redshift.redshift_admin_table_stats'],
#   'model.redshift.stv_partitions': ['model.redshift.redshift_admin_table_stats'],
#   'model.redshift.pg_user': ['model.redshift.redshift_admin_queries',
#    'model.redshift.redshift_admin_users_schema_privileges',
#    'model.redshift.redshift_admin_users_table_view_privileges'],
#   'model.redshift.redshift_columns': [],
#   'model.redshift.redshift_constraints': [],
#   'model.redshift.redshift_sort_dist_keys': [],
#   'model.redshift.redshift_tables': [],
#   'source.VEB_trans_veb.ingest_dynamics.accounts': ['model.VEB_trans_veb.010_dyn_accounts'],
#   'source.VEB_trans_veb.ingest_dynamics.opportunities': ['model.VEB_trans_veb.010_dyn_opportunities'],
#   'source.VEB_trans_veb.ingest_dynamics.opportunitysalesprocesses': [],
#   'source.VEB_trans_veb.ingest_dynamics.roles': ['model.VEB_trans_veb.010_dyn_roles'],
#   'source.VEB_trans_veb.ingest_dynamics.salesorders': [],
#   'source.VEB_trans_veb.ingest_dynamics.systemuserrolescollection': ['model.VEB_trans_veb.010_dyn_systemuserrolescollection'],
#   'source.VEB_trans_veb.ingest_dynamics.systemusers': ['model.VEB_trans_veb.010_dyn_systemusers'],
#   'source.VEB_trans_veb.ingest_dynamics.veb_city': ['model.VEB_trans_veb.010_dyn_veb_city'],
#   'source.VEB_trans_veb.ingest_dynamics.veb_contracts': [],
#   'source.VEB_trans_veb.ingest_dynamics.veb_contractproducts': [],
#   'source.VEB_trans_veb.ingest_dynamics.veb_opportunityproducts': [],
#   'source.VEB_trans_veb.ingest_dynamics.veb_parcels': [],
#   'source.VEB_trans_veb.ingest_dynamics.veb_parcelprojectphases': [],
#   'source.VEB_trans_veb.ingest_dynamics.veb_projects': [],
#   'source.VEB_trans_veb.ingest_dynamics.veb_projectdetails': [],
#   'source.VEB_trans_veb.ingest_dynamics.veb_projectphases': [],
#   'source.VEB_trans_veb.ingest_dynamics.veb_province': ['model.VEB_trans_veb.010_dyn_veb_province'],
#   'source.VEB_trans_veb.ingest_dynamics.veb_country': ['model.VEB_trans_veb.010_dyn_veb_country'],
#   'source.VEB_trans_veb.ingest_dynamics.veb_sector': ['model.VEB_trans_veb.020_dyn_accounts'],
#   'source.VEB_trans_veb.ingest_dynamics.veb_vebproducts': [],
#   'source.VEB_trans_veb.ingest_dynamics.veb_vebproductresources': [],
#   'source.VEB_trans_veb.ingest_dynamics.accounts_csv': [],
#   'source.VEB_trans_veb.ingest_dynamics.opportunities_csv': [],
#   'source.VEB_trans_veb.ingest_dynamics.opportunitysalesprocesses_csv': [],
#   'source.VEB_trans_veb.ingest_dynamics.roles_csv': [],
#   'source.VEB_trans_veb.ingest_dynamics.salesorders_csv': [],
#   'source.VEB_trans_veb.ingest_dynamics.systemuserrolescollection_csv': [],
#   'source.VEB_trans_veb.ingest_dynamics.systemusers_csv': [],
#   'source.VEB_trans_veb.ingest_dynamics.veb_city_csv': [],
#   'source.VEB_trans_veb.ingest_dynamics.veb_contracts_csv': [],
#   'source.VEB_trans_veb.ingest_dynamics.veb_contractproducts_csv': [],
#   'source.VEB_trans_veb.ingest_dynamics.veb_opportunityproducts_csv': [],
#   'source.VEB_trans_veb.ingest_dynamics.veb_parcels_csv': [],
#   'source.VEB_trans_veb.ingest_dynamics.veb_parcelprojectphases_csv': [],
#   'source.VEB_trans_veb.ingest_dynamics.veb_projects_csv': [],
#   'source.VEB_trans_veb.ingest_dynamics.veb_projectdetails_csv': [],
#   'source.VEB_trans_veb.ingest_dynamics.veb_projectphases_csv': [],
#   'source.VEB_trans_veb.ingest_dynamics.veb_province_csv': [],
#   'source.VEB_trans_veb.ingest_dynamics.veb_country_csv': [],
#   'source.VEB_trans_veb.ingest_dynamics.veb_sector_csv': [],
#   'source.VEB_trans_veb.ingest_dynamics.veb_vebproducts_csv': [],
#   'source.VEB_trans_veb.ingest_dynamics.veb_vebproductresources_csv': [],
#   'source.VEB_trans_veb.ingest_business_central.customers': [],
#   'source.VEB_trans_veb.ingest_terra.assetlist': [],
#   'source.VEB_trans_veb.ingest_terra.assetdetaillist': [],
#   'source.VEB_trans_veb.ingest_terra.requestdetaillist': ['model.VEB_trans_veb.kic_2_terra_vs_crm',
#    'model.VEB_trans_veb.kic_5_vkk_no_update_eep'],
#   'source.VEB_trans_veb.ingest_terra.organisationlist': ['model.VEB_trans_veb.020_ter_organisations'],
#   'source.VEB_trans_veb.ingest_terra.datawarehouserequestitem': ['model.VEB_trans_veb.kic_5_vkk_no_update_eep'],
#   'source.VEB_trans_veb.ingest.cogenius_rel': ['model.VEB_trans_veb.020_lynx_rel'],
#   'source.VEB_trans_veb.ingest.cogenius_city': ['model.VEB_trans_veb.020_lynx_rel'],
#   'source.VEB_trans_veb.ingest.basisregister_onderwijs_vlaanderen_vestiging': ['model.VEB_trans_veb.onderwijs_010_dedup'],
#   'source.VEB_trans_veb.ingest.basisregister_onderwijs_vlaanderen_gebouweenheid_adres': ['model.VEB_trans_veb.onderwijs_030_organisatie_basisregister'],
#   'source.VEB_trans_veb.ingest.basisregister_onderwijs_vlaanderen_gebouweenheid': ['model.VEB_trans_veb.onderwijs_030_organisatie_basisregister'],
#   'source.VEB_trans_veb.ingest.basisregister_onderwijs_vlaanderen_gebouweenheid_detail': ['model.VEB_trans_veb.onderwijs_030_organisatie_basisregister'],
#   'source.VEB_trans_veb.ingest.basisregister_onderwijs_vlaanderen_crab_huisnr': [],
#   'source.VEB_trans_veb.ingest.basisregister_onderwijs_vlaanderen_adresmatch': ['model.VEB_trans_veb.onderwijs_030_organisatie_basisregister'],
#   'source.VEB_trans_veb.ingest.basisregister_cobrha_wvg_vestiging': [],
#   'source.VEB_trans_veb.ingest.basisregister_cobrha_wvg_adresmatch': [],
#   'source.VEB_trans_veb.ingest.basisregister_cobrha_wvg_gebouweenheid': [],
#   'source.VEB_trans_veb.ingest.shared_vipa_gkb_instellingen': ['model.VEB_trans_veb.zorg_010_cleaning'],
#   'source.VEB_trans_veb.ingest.basisregister_vipa_adresmatch': ['model.VEB_trans_veb.zorg_030_organisatie_basisregister'],
#   'source.VEB_trans_veb.ingest.basisregister_vipa_gebouweenheid': ['model.VEB_trans_veb.zorg_030_organisatie_basisregister'],
#   'source.VEB_trans_veb.ingest.basisregister_vipa_gebouweenheid_adres': ['model.VEB_trans_veb.zorg_030_organisatie_basisregister'],
#   'source.VEB_trans_veb.ingest.basisregister_vipa_gebouweenheid_detail': ['model.VEB_trans_veb.zorg_030_organisatie_basisregister'],
#   'source.VEB_trans_veb.ingest.bc_creditnotas': ['model.VEB_trans_veb.010_ee_wip_creditnotas'],
#   'source.VEB_trans_veb.ingest.bc_creditnotalines': ['model.VEB_trans_veb.010_ee_wip_creditnotas'],
#   'source.VEB_trans_veb.ingest.bc_postedsalesinvoice': ['model.VEB_trans_veb.010_ee_wip_facturen'],
#   'source.VEB_trans_veb.ingest.bc_postedsalesinvoicesalesinvlines': ['model.VEB_trans_veb.010_ee_wip_facturen'],
#   'source.VEB_trans_veb.ingest.bc_resource': ['model.VEB_trans_veb.010_ee_wip_creditnotas',
#    'model.VEB_trans_veb.010_ee_wip_facturen'],
#   'source.VEB_trans_veb.ingest.7pace_worklogsonly': ['model.VEB_trans_veb.time_tracking_010_7pace_work_logs_only'],
#   'source.VEB_trans_veb.ingest.devops_workitems': ['model.VEB_trans_veb.time_tracking_010_devops_work_items'],
#   'source.VEB_trans_veb.ingest.crm_accounts': ['model.VEB_trans_veb.010_ee_wip_crm',
#    'model.VEB_trans_veb.crm_accounts',
#    'model.VEB_trans_veb.kic_1_eep_vs_crm',
#    'model.VEB_trans_veb.kic_2_terra_vs_crm'],
#   'source.VEB_trans_veb.ingest.crm_opportunities': ['model.VEB_trans_veb.crm_opportunities',
#    'model.VEB_trans_veb.kic_3_vkk_detail',
#    'model.VEB_trans_veb.kic_4_eep_vkk_aanneming',
#    'model.VEB_trans_veb.kic_4_eep_vkk_zonnepanelen',
#    'model.VEB_trans_veb.kic_5_vkk_no_update_eep'],
#   'source.VEB_trans_veb.ingest.crm_opportunitysalesprocesses': ['model.VEB_trans_veb.crm_opportunitysalesprocesses'],
#   'source.VEB_trans_veb.ingest.crm_salesorderdetails': ['model.VEB_trans_veb.crm_salesorderdetails'],
#   'source.VEB_trans_veb.ingest.crm_salesorders': ['model.VEB_trans_veb.crm_salesorders'],
#   'source.VEB_trans_veb.ingest.crm_veb_contractproducts': ['model.VEB_trans_veb.crm_veb_contractproducts'],
#   'source.VEB_trans_veb.ingest.crm_veb_contracts': ['model.VEB_trans_veb.crm_veb_contracts'],
#   'source.VEB_trans_veb.ingest.crm_veb_opportunityproducts': ['model.VEB_trans_veb.crm_veb_opportunityproducts'],
#   'source.VEB_trans_veb.ingest.crm_veb_parcelprojectphases': ['model.VEB_trans_veb.crm_veb_parcelprojectphases'],
#   'source.VEB_trans_veb.ingest.crm_veb_parcels': ['model.VEB_trans_veb.010_ee_wip_crm',
#    'model.VEB_trans_veb.crm_veb_parcels',
#    'model.VEB_trans_veb.kic_2_terra_vs_crm'],
#   'source.VEB_trans_veb.ingest.crm_veb_projectdetails': ['model.VEB_trans_veb.crm_veb_projectdetails'],
#   'source.VEB_trans_veb.ingest.crm_veb_projectphases': ['model.VEB_trans_veb.crm_veb_projectphases'],
#   'source.VEB_trans_veb.ingest.crm_veb_projects': ['model.VEB_trans_veb.010_ee_wip_crm',
#    'model.VEB_trans_veb.crm_veb_projects',
#    'model.VEB_trans_veb.kic_1_eep_vs_crm',
#    'model.VEB_trans_veb.kic_2_terra_vs_crm'],
#   'source.VEB_trans_veb.ingest.crm_veb_vebproductresources': ['model.VEB_trans_veb.crm_veb_vebproductresources'],
#   'source.VEB_trans_veb.ingest.crm_veb_vebproducts': ['model.VEB_trans_veb.010_ee_wip_crm',
#    'model.VEB_trans_veb.crm_veb_vebproducts'],
#   'source.VEB_trans_veb.ingest.eep_productlist': ['model.VEB_trans_veb.010_dim_product_ee'],
#   'source.VEB_trans_veb.ingest.eep_organisationlist': ['model.VEB_trans_veb.010_dim_customer_ee',
#    'model.VEB_trans_veb.010_dim_supplier_ee'],
#   'source.VEB_trans_veb.ingest.eep_productconfigmilestones': ['model.VEB_trans_veb.010_dim_milestone_ee'],
#   'source.VEB_trans_veb.ingest.eep_requestinformationitem': ['model.VEB_trans_veb.010_dim_customer_ee',
#    'model.VEB_trans_veb.010_dim_customercare_ee',
#    'model.VEB_trans_veb.010_dim_operationssupport_ee',
#    'model.VEB_trans_veb.010_dim_projectlead_ee',
#    'model.VEB_trans_veb.010_dim_request_ee',
#    'model.VEB_trans_veb.010_ee_wip_eep_aanneming',
#    'model.VEB_trans_veb.010_ee_wip_eep_details',
#    'model.VEB_trans_veb.010_ee_wip_eep_epc',
#    'model.VEB_trans_veb.010_ee_wip_eep_requestinfo',
#    'model.VEB_trans_veb.010_ee_wip_eep_zonnepanelen_sao',
#    'model.VEB_trans_veb.020_fact_ee_milestone_progression',
#    'model.VEB_trans_veb.kic_1_eep_vs_crm',
#    'model.VEB_trans_veb.kic_4_eep_vkk_aanneming',
#    'model.VEB_trans_veb.kic_4_eep_vkk_zonnepanelen',
#    'model.VEB_trans_veb.kic_5_vkk_no_update_eep'],
#   'source.VEB_trans_veb.ingest.eep_requestlist': ['model.VEB_trans_veb.010_dim_request_ee'],
#   'source.VEB_trans_veb.ingest.eep_requestdynamicstatelistview': ['model.VEB_trans_veb.010_dim_request_ee',
#    'model.VEB_trans_veb.010_ee_wip_eep_aanneming',
#    'model.VEB_trans_veb.010_ee_wip_eep_details',
#    'model.VEB_trans_veb.010_ee_wip_eep_totale_waarde',
#    'model.VEB_trans_veb.020_fact_ee_milestone_progression',
#    'model.VEB_trans_veb.kic_4_eep_vkk_aanneming',
#    'model.VEB_trans_veb.kic_4_eep_vkk_zonnepanelen'],
#   'source.VEB_trans_veb.ingest.eep_requestmilestonelistview': ['model.VEB_trans_veb.010_ee_wip_eep_aanneming',
#    'model.VEB_trans_veb.010_ee_wip_eep_epc',
#    'model.VEB_trans_veb.010_ee_wip_eep_zonnepanelen_sao'],
#   'source.VEB_trans_veb.ingest.eep_requestmilestoneleadtimelistview': ['model.VEB_trans_veb.020_fact_ee_milestone_progression',
#    'model.VEB_trans_veb.020_fact_ee_milestone_progression'],
#   'source.VEB_trans_veb.ingest.eep_requeststatelistview': ['model.VEB_trans_veb.010_ee_wip_eep_details',
#    'model.VEB_trans_veb.010_ee_wip_eep_totale_waarde',
#    'model.VEB_trans_veb.kic_4_eep_vkk_zonnepanelen'],
#   'source.VEB_trans_veb.ingest.eep_userlist': [],
#   'source.VEB_trans_veb.ingest.crm_veb_dynamicproductprices': ['model.VEB_trans_veb.crm_veb_dynamicproductprices'],
#   'source.VEB_trans_veb.project.assignment_timephased_dataset': [],
#   'source.VEB_trans_veb.project.projects': [],
#   'source.VEB_trans_veb.project.resource_timephased_dataset': [],
#   'source.VEB_trans_veb.project.resources': [],
#   'source.VEB_trans_veb.project.task_timephased_dataset': [],
#   'source.VEB_trans_veb.project.taskbaseline_timephased_dataset': [],
#   'source.VEB_trans_veb.project.tasks': [],
#   'source.VEB_trans_veb.project.timesheet_classes': [],
#   'source.VEB_trans_veb.project.timesheet_line_actual_dataset': [],
#   'source.VEB_trans_veb.project.timesheet_lines': [],
#   'source.VEB_trans_veb.project.7pace_work_logs_only': [],
#   'source.VEB_trans_veb.project.7pace_work_logs_only_csv': [],
#   'source.VEB_trans_veb.project.devops_work_items': [],
#   'source.VEB_trans_veb.project.assignment_timephased_dataset_csv': [],
#   'source.VEB_trans_veb.project.projects_csv': [],
#   'source.VEB_trans_veb.project.resource_timephased_dataset_csv': [],
#   'source.VEB_trans_veb.project.resources_csv': [],
#   'source.VEB_trans_veb.project.task_timephased_dataset_csv': [],
#   'source.VEB_trans_veb.project.taskbaseline_timephased_dataset_csv': [],
#   'source.VEB_trans_veb.project.tasks_csv': [],
#   'source.VEB_trans_veb.project.timesheet_classes_csv': [],
#   'source.VEB_trans_veb.project.timesheet_line_actual_dataset_csv': [],
#   'source.VEB_trans_veb.project.timesheet_lines_csv': [],
#   'source.VEB_trans_veb.terra.assetlist': ['model.VEB_trans_veb.onderwijs_040_nieuwe_gebouwen',
#    'model.VEB_trans_veb.zorg_040_nieuwe_gebouwen'],
#   'source.VEB_trans_veb.terra.assetdetaillist': ['model.VEB_trans_veb.onderwijs_075_gebouwen_meerdere_scholen',
#    'model.VEB_trans_veb.zorg_075_gebouwen_meerdere_scholen',
#    'model.VEB_trans_veb.zorg_onderwijs_081_link_pat_to_org_loader',
#    'model.VEB_trans_veb.zorg_onderwijs_082_hoofdgebouwen_loader',
#    'model.VEB_trans_veb.zorg_onderwijs_083_related_asset_loader',
#    'model.VEB_trans_veb.zorg_onderwijs_085_terra_eans'],
#   'source.VEB_trans_veb.terra.organisationlist': ['model.VEB_trans_veb.onderwijs_030_organisatie_basisregister',
#    'model.VEB_trans_veb.zorg_030_organisatie_basisregister',
#    'model.VEB_trans_veb.zorg_onderwijs_081_link_pat_to_org_loader',
#    'model.VEB_trans_veb.zorg_onderwijs_082_hoofdgebouwen_loader',
#    'model.VEB_trans_veb.zorg_onderwijs_085_terra_eans'],
#   'source.VEB_trans_veb.terra.registeredbuildinglist': ['model.VEB_trans_veb.onderwijs_040_nieuwe_gebouwen',
#    'model.VEB_trans_veb.onderwijs_075_gebouwen_meerdere_scholen',
#    'model.VEB_trans_veb.zorg_040_nieuwe_gebouwen',
#    'model.VEB_trans_veb.zorg_060_gebouw_merged',
#    'model.VEB_trans_veb.zorg_075_gebouwen_meerdere_scholen',
#    'model.VEB_trans_veb.zorg_onderwijs_081_link_pat_to_org_loader',
#    'model.VEB_trans_veb.zorg_onderwijs_082_hoofdgebouwen_loader',
#    'model.VEB_trans_veb.zorg_onderwijs_083_related_asset_loader',
#    'model.VEB_trans_veb.zorg_onderwijs_085_terra_eans'],
#   'source.VEB_trans_veb.terra.assetkindlist': ['model.VEB_trans_veb.zorg_onderwijs_081_link_pat_to_org_loader',
#    'model.VEB_trans_veb.zorg_onderwijs_082_hoofdgebouwen_loader',
#    'model.VEB_trans_veb.zorg_onderwijs_085_terra_eans'],
#   'source.VEB_trans_veb.terra.assetorganisationlist': ['model.VEB_trans_veb.zorg_onderwijs_081_link_pat_to_org_loader',
#    'model.VEB_trans_veb.zorg_onderwijs_082_hoofdgebouwen_loader',
#    'model.VEB_trans_veb.zorg_onderwijs_085_terra_eans'],
#   'source.VEB_trans_veb.terra.datawarehouseconnectionpointlist': ['model.VEB_trans_veb.zorg_onderwijs_085_terra_eans'],
#   'source.VEB_trans_veb.terra.connectionpointorganisationlist': ['model.VEB_trans_veb.zorg_onderwijs_085_terra_eans'],
#   'source.VEB_trans_veb.history.connectionpointasset': ['model.VEB_trans_veb.zorg_onderwijs_085_terra_eans'],
#   'source.VEB_trans_veb.ingest_external.time_tracking_config_timesheet': ['model.VEB_trans_veb.time_tracking_7pace_worklogs',
#    'model.VEB_trans_veb.time_tracking_config_timesheet'],
#   'exposure.VEB_trans_veb.survey-email-lists__veb__m&s': [],
#   'exposure.VEB_trans_veb.keep-it-clean__veb__keep-it-clean': [],
#   'exposure.VEB_trans_veb.overzicht-uren__veb__management': [],
#   'exposure.VEB_trans_veb.wip-(nog-niet-gefactureerde-doorrekeningen-en-kdv)__veb__budget': [],
#   'exposure.VEB_trans_veb.opvolging-facturatie__veb__budget': [],
#   'exposure.VEB_trans_veb.doorlooptijden-&-overschrijdingen__veb__timing': []}}
